# %% [markdown]
# # Finishing off the prep data

# %% [markdown]
# ## Imports

# %%
# Imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_seq_items', None)

# %%
# dtype={'type': str} prevents being confused with data type for large data sets
train = pd.read_csv('data/train.csv', index_col='id', dtype={'type': str})
test = pd.read_csv('data/test.csv', index_col='id', dtype={'type': str})
train_translated = pd.read_csv('data/train_translated.csv', dtype={'type': str})
test_translated = pd.read_csv('data/test_translated.csv', index_col='id', dtype={'type': str})
combined_data = pd.read_csv('data/combined_data.csv', index_col='id', dtype={'type': str})
combined_data_translated = pd.read_csv('data/combined_data_translated.csv', index_col='id', dtype={'type': str})
combined_data_fully_translated = pd.read_csv('data/combined_data_fully_translated.csv', index_col='id', dtype={'type': str})
prep = pd.read_csv('data/prep.csv', index_col='id', dtype={'type': str})
# Out:
# C:\Users\daria\AppData\Local\Temp\ipykernel_17612\1699356385.py:9: DtypeWarning: Columns (226,235) have mixed types. Specify dtype option on import or set low_memory=False.
#   prep = pd.read_csv('data/prep.csv', index_col='id', dtype={'type': str})

# %% [markdown]
# ## Add new colunm for each feature

# %% [markdown]
# Features to add a columns for whether the feature has a value:
#
#     - location
#     - participant
#     - damages
#     - collection_additional_nr
#     - participants_role
#     - event_type
#     - city_municipality
#     - country
#     - musealia_additional_nr
#     - is_original
#     - 'class_manufacturer's name', 'class_name on the source document' -> find orginal feature name
#     - museum_abbr
#     - color
#     - collection_mark
#     - state
#     - technique
#     - material
#
#
#     Unsure:
#     - 'startYear', 'startMonth','startDay', 'endYear', 'endMonth', 'endDay'
#     - 'text_features'
#     - 'amount IN pieces', 'circumference IN cm', 'diameter IN cm',
#            'distance IN cm', 'document volume IN pages', 'film frame IN mm²',
#             'height IN cm', 'image height IN cm', 'image width IN cm',
#            'length IN cm', 'negative format IN mm²', 'page height IN cm',
#            'page width IN cm', 'paper format IN A6', 'photo format IN mm²',
#            'print volume IN pages', 'size (clothing) IN number', 'thickness IN cm',
#            'time/ duration IN century', 'volume of the book IN pages',
#            'volume of wood IN dm3', 'volume of writing IN autograph',
#            'weight IN g', 'width IN cm', 'film frame IN mm²_height',
#            'film frame IN mm²_width', 'negative format IN mm²_height',
#            'negative format IN mm²_width', 'photo format IN mm²_height'
#           'photo format IN mm²_width' etc
#     - 'ks', 'musealia_seria_nr', 'musealia_queue_nr', 'collection_queue_nr',
#        'element_count'
#     - city_municipality, country
#
#     Not needed for:
#
#     - before_Christ_no
#     - musealia_mark__
#     - 'location_building', 'location_street', 'location_country', 'location_address'

# %% [markdown]
# ### Defining Fuctions

# %%
# collects all column names that start with col_start
def col_collection(data, col_start):
        cols = []
        for c in data.columns:
            if (c.startswith(col_start)):
                cols.append(c)
        print(str(len(cols)) + ' columns found that start with ' + str(col_start))
        return cols

# %%
# creates a new column col_start_has_a_value that states whether that feature has a value or is NaN
# aware this is very inefficient - might use for some cases  
def feature_has_value(data, col_start):
        cols = col_collection(data, col_start)
        data[str(col_start)+'_has_a_value'] = 0
        for i in data.index:
            for c in cols:
                if (data.loc[i][c] == 1):
                    data.at[i, (str(col_start)+'_has_a_value')]  = 1 
                    continue

# %%
# creates a new column for each column in cols. Each column shows whether an instance has a value(1) or a NaN (0) for that feature
def add_feature_has_value_cols(data, org_data, cols):
    for c in cols:
        data[str(c)+'_has_a_value'] =  org_data[c].apply(lambda x: 0 if pd.isnull(x) else 1)
    return data

# %% [markdown]
# ### Apply to features

# %%
#copy of hot encoded data
data = prep.copy()

# %%
#data pre manipulation
org_data = combined_data_fully_translated.copy()

# %%
#list of all columns to be added
cols = ['location', 'participant', 'damages', 'collection_additional_nr', 'participants_role', 'event_type',  'musealia_additional_nr','is_original', 'class', 'museum_abbr', 'color', 'collection_mark', 'state', 'technique', 'material']

# %%
data = add_feature_has_value_cols(data, org_data, cols)

# %%
data.columns
# Out:
# Index(['ks', 'musealia_seria_nr', 'musealia_queue_nr', 'collection_queue_nr',
#        'element_count', 'type', 'source', 'material_Polish',
#        'material_RC Photo Paper', 'material_a pearl',
#        'material_acetate cellulose film', 'material_albumen paper',
#        'material_albumin paper', 'material_aluminium', 'material_amber',
#        'material_artificial fiber material', 'material_artificial leather',
#        'material_artificial material', 'material_atlas',
#        'material_ballpoint pen ink', 'material_birch', 'material_bone',
#        'material_brass', 'material_brocade (clothing variety)',
#        'material_bronze', 'material_canvas', 'material_canvas (type of cloth)',
#        'material_cardboard', 'material_cast iron', 'material_celluloid',
#        'material_ceramics', 'material_chalk', 'material_chamois leather',
#        'material_chamotte', 'material_charcoal', 'material_chromogen emulsion',
#        'material_chromogen paper', 'material_clay',
#        'material_clothing variety', 'material_collodion paper',
#        'material_colloid paper', 'material_colour', 'material_copper',
#        'material_cotton', 'material_crepe', 'material_crepe (cloth type)',
#        'material_crystal', 'material_diffusion paper', 'material_email',
#        'material_emulsion', 'material_enamel paint', 'material_faience',
#        'material_feather', 'material_film', 'material_film (material)',
#        'material_flint', 'material_from the bat', 'material_glass',
#        'material_gold', 'material_granite', 'material_graphite',
#        'material_gypsum', 'material_handmade paper', 'material_ink',
#        'material_iron', 'material_kalka', 'material_knitwear',
#        'material_leotard (type of clothing)', 'material_linen',
#        'material_mascara', 'material_metal', 'material_metal fibers',
#        'material_moire (clothing variety)', 'material_movie', 'material_nan',
#        'material_newsprint', 'material_nitrocellulose film', 'material_nut',
#        'material_oil paint', 'material_organic matter', 'material_paper',
#        'material_papier mache', 'material_photo emulsion',
#        'material_photo material', 'material_photo paper',
#        'material_photo plate', 'material_photographic material',
#        'material_plastic', 'material_plastic mass', 'material_plywood',
#        'material_porcelain', 'material_printing ink', 'material_quartz',
#        'material_rubber', 'material_salt paper', 'material_silk',
#        'material_silver', 'material_silver gelatin emulsion',
#        'material_silver gelatin paper', 'material_skin', 'material_slate',
#        'material_stone', 'material_synthetic fibers',
#        'material_synthetic material', 'material_tempera', 'material_textile',
#        'material_tin', 'material_trillion', 'material_watercolor paint',
#        'material_wax', 'material_white metal', 'material_wire',
#        'material_wood', 'material_wood material', 'material_wooden board',
#        'material_wool', 'material_yarn', 'technique_(close/together) sewing',
#        'technique_addition', 'technique_aquatint', 'technique_ballpoint pen',
#        'technique_binding techniques', 'technique_black and white photo',
#        'technique_black and white photography', 'technique_bronzing',
#        'technique_brushing', 'technique_burning', 'technique_carving',
#        'technique_casting', 'technique_chalk', 'technique_charcoal',
#        'technique_chromogen procedure', 'technique_collage',
#        'technique_collotype', 'technique_color photo',
#        'technique_color photography', 'technique_colored chalk',
#        'technique_colored pencil', 'technique_coloring',
#        'technique_copper engraving', 'technique_copying',
#        'technique_crayon drawing', 'technique_croaking',
#        'technique_crocheting', 'technique_cutting', 'technique_cuttlefish',
#        'technique_daguerreotype', 'technique_digital photography',
#        'technique_digital printing', 'technique_drawing',
#        'technique_electronic imaging', 'technique_embroidery',
#        'technique_enamelling', 'technique_engraving', 'technique_etching',
#        'technique_felt tip pen', 'technique_glass technology',
#        'technique_gouache', 'technique_graphics', 'technique_graphite',
#        'technique_handicraft', 'technique_handwriting', 'technique_ink',
#        'technique_ink drawing', 'technique_intarsia',
#        'technique_kiln ceramics', 'technique_knitting',
#        'technique_letterpress with raster cliché', 'technique_linocut',
#        'technique_lithography', 'technique_manuscript', 'technique_marker',
#        'technique_mascara', 'technique_mezzotinto', 'technique_mixed media',
#        'technique_modeling', 'technique_molding', 'technique_monotypy',
#        'technique_nan', 'technique_offset printing', 'technique_oil',
#        'technique_oil painting', 'technique_painting',
#        'technique_painting techniques', 'technique_pannotype',
#        'technique_pastel', 'technique_pen',
#        'technique_photographic techniques', 'technique_photography',
#        'technique_photogravure', 'technique_photolithography',
#        'technique_photomechanical printing', 'technique_polishing',
#        'technique_pressing', 'technique_printing', 'technique_raster printing',
#        'technique_relief', 'technique_rishel casting heel',
#        'technique_sanguine', 'technique_serigraphy', 'technique_sewing',
#        'technique_sketch', 'technique_slide', 'technique_soft varnish',
#        'technique_stamping', 'technique_steel engraving',
#        'technique_strengthening', 'technique_taking pictures',
#        'technique_tempera', 'technique_toning', 'technique_turning',
#        'technique_typescript', 'technique_typing', 'technique_undermining',
#        'technique_watercolor', 'technique_wet collodion process',
#        'technique_wood engraving', 'technique_woodcut', 'technique_writing',
#        '* IN *', 'amount IN pieces', 'circumference IN cm', 'diameter IN cm',
#        'distance IN cm', 'document volume IN pages', 'film frame IN mm²',
#        'height IN cm', 'image height IN cm', 'image width IN cm',
#        'length IN cm', 'negative format IN mm²', 'page height IN cm',
#        'page width IN cm', 'paper format IN A6', 'photo format IN mm²',
#        'print volume IN pages', 'size (clothing) IN number', 'thickness IN cm',
#        'time/ duration IN century', 'volume of the book IN pages',
#        'volume of wood IN dm3', 'volume of writing IN autograph',
#        'weight IN g', 'width IN cm', 'film frame IN mm²_height',
#        'film frame IN mm²_width', 'negative format IN mm²_height',
#        'negative format IN mm²_width', 'photo format IN mm²_height',
#        'photo format IN mm²_width', 'text_features', 'startYear', 'startMonth',
#        'startDay', 'endYear', 'endMonth', 'endDay', 'location_city',
#        'location_building', 'location_street', 'location_country',
#        'location_address', 'state_bad', 'state_good', 'state_satisfactory',
#        'state_unspecified', 'state_very bad', 'collection_mark_A',
#        'collection_mark_Ab', 'collection_mark_Af', 'collection_mark_Aj',
#        'collection_mark_Ar', 'collection_mark_D', 'collection_mark_Df',
#        'collection_mark_Dg', 'collection_mark_E', 'collection_mark_F',
#        'collection_mark_F154', 'collection_mark_F158', 'collection_mark_Fk',
#        'collection_mark_Fm', 'collection_mark_G', 'collection_mark_Gk',
#        'collection_mark_Hp', 'collection_mark_K', 'collection_mark_K-',
#        'collection_mark_M', 'collection_mark_ML', 'collection_mark_Mi',
#        'collection_mark_Mo', 'collection_mark_N', 'collection_mark_P',
#        'collection_mark_P-', 'collection_mark_PA', 'collection_mark_PB',
#        'collection_mark_PK', 'collection_mark_R-', 'collection_mark_Sk',
#        'collection_mark_T', 'collection_mark_TE', 'color_beige', 'color_black',
#        'color_black and white', 'color_blue', 'color_brown', 'color_golden',
#        'color_green', 'color_grey', 'color_monochrome', 'color_multicolored',
#        'color_orange', 'color_patterned', 'color_pink', 'color_red',
#        'color_silver', 'color_transparent', 'color_violet', 'color_white',
#        'color_yellow', 'museum_abbr_AM', 'museum_abbr_ETMM',
#        'class_manufacturer's name', 'class_name on the source document',
#        'is_original_0.0', 'is_original_1.0', 'musealia_mark__',
#        'before_Christ_no', 'musealia_additional_nr_01.veebr',
#        'musealia_additional_nr_1', 'musealia_additional_nr_2',
#        'musealia_additional_nr_3', 'musealia_additional_nr_4',
#        'musealia_additional_nr_5', 'musealia_additional_nr_6',
#        'musealia_additional_nr_R', 'musealia_additional_nr_a',
#        'musealia_additional_nr_below_thres', 'country_Ameerika Ühendriigid',
#        'country_Austria', 'country_Eesti', 'country_Inglismaa',
#        'country_Kanada', 'country_Kasahstan', 'country_Läti', 'country_NSVL',
#        'country_Prantsusmaa', 'country_Rootsi', 'country_Saksamaa',
#        'country_Soome', 'country_Vene', 'country_Venemaa',
#        'country_below_thres', 'city_municipality_Haapsalu',
#        'city_municipality_Harju', 'city_municipality_Ida-Viru',
#        'city_municipality_Kesklinna', 'city_municipality_Kohtla-Järve',
#        'city_municipality_Kuressaare', 'city_municipality_Kõmsi',
#        'city_municipality_Narva', 'city_municipality_Narva-Jõesuu',
#        'city_municipality_Otepää', 'city_municipality_Pärnu',
#        'city_municipality_Rakvere', 'city_municipality_Setomaa vald',
#        'city_municipality_Tallinn', 'city_municipality_Tartu',
#        'city_municipality_Tartumaa', 'city_municipality_Valga',
#        'city_municipality_Viljandi', 'city_municipality_Võru',
#        'city_municipality_below_thres', 'event_type_Agriculture',
#        'event_type_There is no KVIS event', 'event_type_anniversary birthdays',
#        'event_type_appearances', 'event_type_archaeological excavation',
#        'event_type_archaeological excavations', 'event_type_archaeology',
#        'event_type_architecture', 'event_type_army', 'event_type_arrangement',
#        'event_type_awarding', 'event_type_ballet', 'event_type_below_thres',
#        'event_type_biographies', 'event_type_birthdays', 'event_type_bombing',
#        'event_type_caricatures', 'event_type_ceramics (applied art)',
#        'event_type_churches', 'event_type_cities',
#        'event_type_collecting/finding',
#        'event_type_collection activities of the museum',
#        'event_type_collective farms/cooperatives',
#        'event_type_competitions - inspections', 'event_type_composing',
#        'event_type_concert trips/tours', 'event_type_concerts',
#        'event_type_copying (making)', 'event_type_correspondence',
#        'event_type_cultural history', 'event_type_culture',
#        'event_type_dance parties', 'event_type_dancing',
#        'event_type_documentation', 'event_type_doing choral singing',
#        'event_type_drafting', 'event_type_education', 'event_type_elections',
#        'event_type_ethnology', 'event_type_exhibition', 'event_type_family',
#        'event_type_fiction', 'event_type_filming',
#        'event_type_filmmaking and photography', 'event_type_films (works)',
#        'event_type_finance', 'event_type_food trade',
#        'event_type_foreign Estonians', 'event_type_funeral',
#        'event_type_furniture industry', 'event_type_graphics (visual arts)',
#        'event_type_group portrait', 'event_type_history',
#        'event_type_industry', 'event_type_information storage',
#        'event_type_instrumental music', 'event_type_landscapes',
#        'event_type_lifestyle/living situation', 'event_type_literature',
#        'event_type_making by hand', 'event_type_making music and singing',
#        'event_type_making musical instruments',
#        'event_type_making/originating', 'event_type_male choirs',
#        'event_type_manuscript preparation', 'event_type_memories',
#        'event_type_metal art', 'event_type_military and defense',
#        'event_type_mixed choirs', 'event_type_museum work', 'event_type_music',
#        'event_type_music education', 'event_type_music festivals',
#        'event_type_music history', 'event_type_music, theater, dance',
#        'event_type_new year/ gums', 'event_type_operas',
#        'event_type_operettas', 'event_type_pedagogy',
#        'event_type_personal and family life', 'event_type_photography',
#        'event_type_photos (works)', 'event_type_playwriting',
#        'event_type_politics', 'event_type_portrait of a man',
#        'event_type_portraiture', 'event_type_preparation',
#        'event_type_printing/ publishing', 'event_type_propaganda/campaign',
#        'event_type_puppet theater', 'event_type_reference literature',
#        'event_type_religion and beliefs', 'event_type_rest/ free time',
#        'event_type_revolution', 'event_type_school life',
#        'event_type_singing parties', 'event_type_societies',
#        'event_type_solo song', 'event_type_square/square',
#        'event_type_state and society', 'event_type_street',
#        'event_type_taking pictures', 'event_type_telegraph',
#        'event_type_the press', 'event_type_theater',
#        'event_type_theater activity', 'event_type_theater criticism',
#        'event_type_theater education', 'event_type_theater history',
#        'event_type_theater performances', 'event_type_trade',
#        'event_type_trading/shop', 'event_type_travelling',
#        'event_type_vocal music', 'event_type_wars', 'event_type_word plays',
#        'event_type_writing', 'participants_role_a dancer',
#        'participants_role_a singer', 'participants_role_actor',
#        'participants_role_addressee', 'participants_role_an artist',
#        'participants_role_author of the text', 'participants_role_below_thres',
#        'participants_role_collector', 'participants_role_compiler',
#        'participants_role_composer', 'participants_role_conductor',
#        'participants_role_contact person', 'participants_role_device author',
#        'participants_role_director', 'participants_role_editor',
#        'participants_role_engraver', 'participants_role_imagined',
#        'participants_role_liaison organization', 'participants_role_maker',
#        'participants_role_musician', 'participants_role_participant',
#        'participants_role_performer', 'participants_role_photographer',
#        'participants_role_printer (maker)', 'participants_role_publisher',
#        'participants_role_the arranger', 'participants_role_the author',
#        'participants_role_the issuer', 'participants_role_the owner',
#        'participants_role_transferor', 'participants_role_translator',
#        'participants_role_user/owner', 'parish_Harjumaa', 'parish_Pärnumaa',
#        'parish_below_thres', 'collection_additional_nr_01:01',
#        'collection_additional_nr_01:02', 'collection_additional_nr_01:03',
#        'collection_additional_nr_01:04', 'collection_additional_nr_01:05',
#        'collection_additional_nr_01:06', 'collection_additional_nr_02:01',
#        'collection_additional_nr_02:02', 'collection_additional_nr_03:01',
#        'collection_additional_nr_03:02', 'collection_additional_nr_05:01',
#        'collection_additional_nr_06:01', 'collection_additional_nr_06:02',
#        'collection_additional_nr_08:01', 'collection_additional_nr_09:01',
#        'collection_additional_nr_09:03', 'collection_additional_nr_10:01',
#        'collection_additional_nr_12:01', 'collection_additional_nr_13:01',
#        'collection_additional_nr_13:02', 'collection_additional_nr_14:01',
#        'collection_additional_nr_16:02', 'collection_additional_nr_34:01:00',
#        'collection_additional_nr_Ar', 'collection_additional_nr_M',
#        'collection_additional_nr_T', 'collection_additional_nr_T185',
#        'collection_additional_nr_a', 'collection_additional_nr_below_thres',
#        'collection_additional_nr_d', 'collection_additional_nr_k',
#        'collection_additional_nr_kl', 'collection_additional_nr_r',
#        'collection_additional_nr_t', 'damages_All right', 'damages_Cracked',
#        'damages_The album pages are deformed, there are tears and bruises, the binding holes are broken.',
#        'damages_below_thres', 'damages_cracked', 'damages_dirty',
#        'damages_fracture lines', 'damages_glue marks on the back',
#        'damages_pin holes', 'damages_traces of glue',
#        'damages_traces of glue on the back', 'damages_worn out',
#        'damages_wrinkled', 'damages_yellowed', 'damages_yellowed, dirty',
#        'participant_Aav, Evald', 'participant_Aavik, Juhan',
#        'participant_Agur, Ingrid', 'participant_Akel, Karl',
#        'participant_Alla, Armin', 'participant_Areng, Kuno', 'participant_Art',
#        'participant_Avesson, Elsa', 'participant_Draamateater',
#        'participant_ENSV Riiklik Vene Draamateater',
#        'participant_Eesti Draamateater',
#        'participant_Eesti NSV Kultuuriministeerium. Teatrite Valitsus',
#        'participant_Eesti NSV Kunstide Valitsus',
#        'participant_Eesti Teatriliit', 'participant_Eller, Heino',
#        'participant_Ernesaks, Gustav', 'participant_Estonia Muusika Osakond',
#        'participant_Estonia Selts', 'participant_Franz, Erika',
#        'participant_Georg Otsa nimeline Tallinna Muusikakool',
#        'participant_Goldschmidt, Nikolai', 'participant_Grepp, Priit',
#        'participant_Haan, Kalju', 'participant_Heinrich III',
#        'participant_J. & P. Parikas', 'participant_Jakobson, August',
#        'participant_Järvi, Neeme', 'participant_Jõgi, Ants',
#        'participant_Kaljuste, Heino', 'participant_Kalmet, Leo',
#        'participant_Kapp, Eugen', 'participant_Karindi, Alfred',
#        'participant_Karrisoo, Eedo', 'participant_Kausi, Albina',
#        'participant_Klas, Eri', 'participant_Klaus, Leida',
#        'participant_Koemets, Aleksander',
#        'participant_Kohtla-Järve Vene Draamateater',
#        'participant_Kreek, Cyrillus', 'participant_Kunstide Valitsus',
#        'participant_Kurman, Juta', 'participant_Känd, Herman',
#        'participant_Kärner, Rein', 'participant_Laagriküll, Jaanus',
#        'participant_Laid, Milvi', 'participant_Laidla, Silvia',
#        'participant_Laul, Mart', 'participant_Laur, Hugo',
#        'participant_Leichter, Karl', 'participant_Leinus, Karl',
#        'participant_Lemba, Artur', 'participant_Lepnurm, Hugo',
#        'participant_Lukin, E.', 'participant_Luts, Oskar',
#        'participant_Lüdig, Mihkel', 'participant_Matsov, Roman',
#        'participant_Mei, Natalie', 'participant_Mesikäpp, Laine',
#        'participant_Mikiver, Mikk', 'participant_Mägi, Ester',
#        'participant_Naissoo, Uno', 'participant_Noorsooteater',
#        'participant_Nurmik, Leemet', 'participant_O'Ya, Bruno',
#        'participant_Oksbusch, Uno', 'participant_Orgulas, Jaanus',
#        'participant_Orumets, Vello', 'participant_Ots, Georg',
#        'participant_Panso, Voldemar', 'participant_Parikas, Marje',
#        'participant_Philipp Reclam', 'participant_Pihlak, Liina',
#        'participant_Pinna, Paul', 'participant_Podelski, Gennadi',
#        'participant_Poljakov, Jüri', 'participant_Proosa, Alan',
#        'participant_Pärt, Arvo', 'participant_Päts, Riho',
#        'participant_Püüman, Kustav-Agu', 'participant_Rahvusooper Estonia',
#        'participant_Rakvere Teater', 'participant_Reimann, Villu',
#        'participant_Ringo, Richard', 'participant_SA NUKU',
#        'participant_Saar, Mart', 'participant_Saarne, Henno',
#        'participant_Sander, Georg', 'participant_Schlater, Georg Friedrich',
#        'participant_Shakespeare, William', 'participant_Sillasoo, Avo',
#        'participant_Simm, Juhan', 'participant_Sirin, Vjatšeslav',
#        'participant_Sisask, Urmas', 'participant_Soosaar, Hans',
#        'participant_Sumera, Lepo', 'participant_Sunne, August',
#        'participant_Suur, Kalju', 'participant_Säre, Meeri',
#        'participant_Särev, Andres', 'participant_Sõrmus, Eduard',
#        'participant_Süda, Peeter', 'participant_Süld, Jaana',
#        'participant_TASS-i fotokroonika', 'participant_Talivee, Enno',
#        'participant_Tallinna Linnateater', 'participant_Tamarkin, Aron',
#        'participant_Tamm, Aino', 'participant_Taniloo, Kadi',
#        'participant_Teater Endla', 'participant_Teater Estonia',
#        'participant_Teater Ugala', 'participant_Teater Vanemuine',
#        'participant_Teppor, Alexander', 'participant_Tormis, Veljo',
#        'participant_Trilljärv, Aleksander', 'participant_Tubin, Eduard',
#        'participant_Tundmatu 19. sajandi kunstnik', 'participant_Ugala Teater',
#        'participant_Uibo, Uno', 'participant_Ungern-Sternberg, Carl',
#        'participant_Unt, Aime', 'participant_VAT Teater',
#        'participant_Vahur, Siim', 'participant_Vaidla, Gunnar',
#        'participant_Vaks, Heino', 'participant_Vannas, Maimu',
#        'participant_Vedro, Adolf', 'participant_Veike, Ferdinand',
#        'participant_Vellema, Leo', 'participant_Velmet, Aado',
#        'participant_Vettik, Tuudur', 'participant_Viisimaa, Aarne',
#        'participant_Vilde, Ivar', 'participant_Visnapuu, Eduard',
#        'participant_Zeiger, Horre', 'participant_below_thres',
#        'participant_tundmatu', 'participant_von Plettenberg, Wolter',
#        'participant_Üksip, Albert', 'location_aadress Aia 15',
#        'location_aadress Aleksander Puškini 6', 'location_aadress Dunkri 5',
#        'location_aadress Gonsiori 2 / Kaubamaja 1',
#        'location_aadress Gonsiori 2 / Kaubamaja 1 ',
#        'location_aadress Juhkentali 58', 'location_aadress Järve tee 9',
#        'location_aadress Kalda tn. 6', 'location_aadress Kohtu 6',
#        'location_aadress Komandandi 9', 'location_aadress Lossi plats 7',
#        'location_aadress Maarjamäe loss, Pirita tee 56',
#        'location_aadress Müürivahe 11 / Suur-Karja 15',
#        'location_aadress Müürivahe 12', 'location_aadress Pikk 10',
#        'location_aadress Pikk 17', 'location_aadress Pirita tee 56',
#        'location_aadress Sakala 35',
#        'location_aadress Suurgildi hoone (Börsihoone), Pikk 17',
#        'location_aadress Suurgildi hoone, Pikk 17',
#        'location_aadress Toom-Kooli 6', 'location_aadress Toomkooli 6',
#        'location_aadress Tuule 14', 'location_aadress Uus-Sadama tn 14',
#        'location_aadress Vene 11', 'location_aadress Vene 16',
#        'location_aadress Vilde tee 75',
#        'location_administratiivne üksus Porošino',
#        'location_administratiivne üksus Tamme staadion',
#        'location_alev Kanepi', 'location_alev Puhja', 'location_alev Toila',
#        'location_alevik Võsu', 'location_asula Halila',
#        'location_asula Mahtra', 'location_asum Rocca al Mare',
#        'location_asum Toompea', 'location_asum Vanalinn',
#        'location_hoone - rajatis "Estonia" teater',
#        'location_hoone - rajatis Bauska linnus',
#        'location_hoone - rajatis Deutsches Theater Berlin',
#        'location_hoone - rajatis Draamateater',
#        'location_hoone - rajatis Draamateatri ruumes',
#        'location_hoone - rajatis Esseni Rahvateater',
#        'location_hoone - rajatis Estonia Kontserdisaal',
#        'location_hoone - rajatis Estonia kontserdisaal',
#        'location_hoone - rajatis Estonia teater',
#        'location_hoone - rajatis Haapsalu Toomkirik',
#        'location_hoone - rajatis Harju-Jaani kirik',
#        'location_hoone - rajatis Jaani kirik',
#        'location_hoone - rajatis Jägala Puidumassi vabrik',
#        'location_hoone - rajatis Kadrioru staadion',
#        'location_hoone - rajatis Kaubahall',
#        'location_hoone - rajatis Kiek in de Kök',
#        'location_hoone - rajatis Kinomaja',
#        'location_hoone - rajatis Kirbla Püha Nikolause kirik',
#        'location_hoone - rajatis Kohvik Tallinn',
#        'location_hoone - rajatis Kolhoos Linda administratiivhoone',
#        'location_hoone - rajatis Kommunaalmasinate eksperimentaal remonditehas (KERT)',
#        'location_hoone - rajatis Kopli jaam',
#        'location_hoone - rajatis Kõpu Peetri kirik',
#        'location_hoone - rajatis Lõhavere linnamägi',
#        'location_hoone - rajatis Meremõisa varemed',
#        'location_hoone - rajatis Mustamäe suusahüppetorn',
#        'location_hoone - rajatis Mööblimaja',
#        'location_hoone - rajatis Narva-Jõesuu rannahoone',
#        'location_hoone - rajatis Oleviste kirik',
#        'location_hoone - rajatis Padise klooster',
#        'location_hoone - rajatis Patkuli vaateplatvorm',
#        'location_hoone - rajatis Petseri klooster',
#        'location_hoone - rajatis Pärnu Vabadussõja mälestussammas',
#        'location_hoone - rajatis Pärnu vallikraav',
#        'location_hoone - rajatis Pääsküla raudteejaam',
#        'location_hoone - rajatis Rakvere Teater',
#        'location_hoone - rajatis Riia Ooperiteater',
#        'location_hoone - rajatis Riigikogu hoone',
#        'location_hoone - rajatis Rõuge Püha Neitsi Maarja kirik',
#        'location_hoone - rajatis Sangaste Andrease kirik',
#        'location_hoone - rajatis Sindi kalevivabrik',
#        'location_hoone - rajatis Särevi Teatrituba',
#        'location_hoone - rajatis Sütiste maja',
#        'location_hoone - rajatis Tallinna Kaubamaja',
#        'location_hoone - rajatis Tallinna Konservatoorium',
#        'location_hoone - rajatis Tallinna Kunstihoone',
#        'location_hoone - rajatis Tallinna Toomkool',
#        'location_hoone - rajatis Tallinna lauluväljak',
#        'location_hoone - rajatis Tallinna raekoda',
#        'location_hoone - rajatis Tallinna Ülikooli peamaja',
#        'location_hoone - rajatis Tapa jaamahoone',
#        'location_hoone - rajatis Tartu Kesklinna Kaubahall',
#        'location_hoone - rajatis Tartu Metallkaupade Vabrik',
#        'location_hoone - rajatis Tartu Riikliku Ülikooli kohvik',
#        'location_hoone - rajatis Tartu Toomkirik',
#        'location_hoone - rajatis Teaduste akadeemia ',
#        'location_hoone - rajatis Teater Estonia',
#        'location_hoone - rajatis Tehas Eesti kaabel',
#        'location_hoone - rajatis Toompea',
#        'location_hoone - rajatis Toompea linnus',
#        'location_hoone - rajatis V. Kingissepa nimeline Teraviljakombinaat',
#        'location_hoone - rajatis Vabaduse väljak',
#        'location_hoone - rajatis Vanemuise kontserdisaal',
#        'location_hoone - rajatis Versaille`s',
#        'location_hoone - rajatis Viljandi Jaani kirik',
#        'location_hoone - rajatis Viljandi lossivaremed',
#        'location_hoone - rajatis Voltveti raudteejaam',
#        'location_hoone - rajatis Vändra Martini kirik',
#        'location_hoone - rajatis Wiiralti kohvik', 'location_järv Väike viik',
#        'location_jõgi Keila juga', 'location_kalmistu Metsakalmistu',
#        'location_küla Komarovka', 'location_küla Raja', 'location_küla Saha',
#        'location_küla Tsistre ', 'location_küla Urvaste',
#        'location_linn Adelaide', 'location_linn Andaraba',
#        'location_linn Andernach', 'location_linn Asnières-sur-Seine',
#        'location_linn Augsburg', 'location_linn Bagdad (Madinat as-Salam)',
#        'location_linn Bedford', 'location_linn Berliin',
#        'location_linn Berlin', 'location_linn Birmingham',
#        'location_linn Bonn', 'location_linn Brandenburg',
#        'location_linn Braunschweig', 'location_linn Bremerhaven',
#        'location_linn Breslau', 'location_linn Brüssel',
#        'location_linn Budapest', 'location_linn Buhhaara',
#        'location_linn Bukarest', 'location_linn Bulgar',
#        'location_linn Cassel', 'location_linn Chichester',
#        'location_linn Danzig', 'location_linn Deventer',
#        'location_linn Deventer või järelmünt', 'location_linn Dorpat',
#        'location_linn Dortmund', 'location_linn Dover',
#        'location_linn Duisburg', 'location_linn Erfurt',
#        'location_linn Erfurt Leipzig', 'location_linn Essen',
#        'location_linn Firenze', 'location_linn Frankfurt',
#        'location_linn Fritzlar', 'location_linn Gittelde',
#        'location_linn Goslar', 'location_linn Goslar?',
#        'location_linn Göteborg', 'location_linn Haapsalu',
#        'location_linn Halberstadt', 'location_linn Halle',
#        'location_linn Hamburg', 'location_linn Harkov',
#        'location_linn Helsingi', 'location_linn Helsinki',
#        'location_linn Hämeenlinna', 'location_linn Irkutsk',
#        'location_linn Istanbul', 'location_linn Jena', 'location_linn Jurjev',
#        'location_linn Jurjew', 'location_linn Kaasan',
#        'location_linn Karaganda', 'location_linn Kieff',
#        'location_linn Kiviõli', 'location_linn Klaipeda',
#        'location_linn Konstanz', 'location_linn Kosice', 'location_linn Köln',
#        'location_linn Leipzig', 'location_linn Leningrad',
#        'location_linn Leningrad-Moskva', 'location_linn Liepaja',
#        'location_linn Lincoln', 'location_linn Lissabon',
#        'location_linn Lleipzig', 'location_linn London', 'location_linn Loska',
#        'location_linn Lund', 'location_linn Magdeburg', 'location_linn Mainz',
#        'location_linn Marienburg/Aluksne', 'location_linn Ma´din',
#        'location_linn Moscau', 'location_linn Moskva',
#        'location_linn Moskva-Leningrad', 'location_linn München',
#        'location_linn München, Leipzig', 'location_linn Münster',
#        'location_linn Naapoli', 'location_linn Namur', 'location_linn Narva',
#        'location_linn New York', 'location_linn Northampton',
#        'location_linn Nördlingen', 'location_linn Oxford',
#        'location_linn Paide', 'location_linn Paldiski',
#        'location_linn Panevežys', 'location_linn Pariis',
#        'location_linn Paris', 'location_linn Peterburg',
#        'location_linn Peterburi', 'location_linn Petseri',
#        'location_linn Prüm? St. Goar?', 'location_linn Pärnu',
#        'location_linn Pärnu ', 'location_linn Põlva',
#        'location_linn Quedlinburg', 'location_linn Rakvere',
#        'location_linn Regensburg', 'location_linn Reval', 'location_linn Riga',
#        'location_linn Riia', 'location_linn Rootsi', 'location_linn Roskilde',
#        'location_linn Samarkand', 'location_linn Sankt-Peterburg',
#        'location_linn Shell', 'location_linn Sigtuna', 'location_linn Sindi',
#        'location_linn Soest', 'location_linn Speyer',
#        'location_linn St. Petersbourg', 'location_linn St.Peterburg',
#        'location_linn Stamford', 'location_linn Stockholm',
#        'location_linn Strassburg', 'location_linn Stuttgart',
#        'location_linn Stuttgart, berlin', 'location_linn Suhhumi',
#        'location_linn Suure-Jaani', 'location_linn Tallinn',
#        'location_linn Tallinn ', 'location_linn Tallinna vanalinn',
#        'location_linn Tapa', 'location_linn Tartu',
#        'location_linn Taškent (aš-Šaš)', 'location_linn Tbilisi',
#        'location_linn Tiel', 'location_linn Tübingen', 'location_linn Türi',
#        'location_linn Tšeropovetsk', 'location_linn Valga',
#        'location_linn Varssavi', 'location_linn Vene',
#        'location_linn Vesterås', 'location_linn Viin',
#        'location_linn Viljandi', 'location_linn Viljandi ',
#        'location_linn Vilnius', 'location_linn Voronež', 'location_linn Võnnu',
#        'location_linn Võru', 'location_linn Wareham', 'location_linn Wien',
#        'location_linn Winchester', 'location_linn Worms',
#        'location_linn Wroclaw', 'location_linn Würzburg', 'location_linn York',
#        'location_linn halberstadt', 'location_linn jena',
#        'location_linn järelmünt', 'location_linn leipzig',
#        'location_linn tartu', 'location_linn Пярну', 'location_linnaosa Kopli',
#        'location_linnus Jaanilinna linnus', 'location_linnus Soontagana',
#        'location_linnus Toompea', 'location_linnus Viljandi ordulinnus',
#        'location_linnus Võnnu', 'location_maakond Järva',
#        'location_maakond Petseri', 'location_maakond Tartumaa',
#        'location_maakond Valgamaa', 'location_maakond Viljandimaa',
#        'location_mägi Kazbek', 'location_määramata Blagoveštšensk',
#        'location_määramata Eesti Ajaloomuuseum',
#        'location_määramata Harju-Jaani khk', 'location_määramata Helsingi',
#        'location_määramata Irboska, Pihkva oblast',
#        'location_määramata Jekaterinoslavl (Dnepropetrovsk)',
#        'location_määramata Kadriorg', 'location_määramata Kamarovka',
#        'location_määramata Keila-Joa mõis', 'location_määramata Kingissepp',
#        'location_määramata Köningsee', 'location_määramata Moskva',
#        'location_määramata München',
#        'location_määramata Narva jõe idapoolne kallas',
#        'location_määramata Otepää linnus', 'location_määramata Petseri',
#        'location_määramata Petseri, Pihkva oblast',
#        'location_määramata Pihvkva oblast, Petseri (Setumaa)',
#        'location_määramata Primorje krai', 'location_määramata Riia',
#        'location_määramata Soome laht', 'location_määramata Viiburi',
#        'location_määramata Viktor Kingissepa mälestussammas',
#        'location_määramata Vladivostok, Liflandia küla',
#        'location_määramata Võnnu (Cesis)', 'location_määramata Waldemode',
#        'location_määramata [Narva-Jõesuu]', 'location_määramata [Raplamaa]',
#        'location_määramata [Tallinn]', 'location_mõis Olustvere mõis',
#        'location_mõis Türi-Alliku', 'location_oblast Karaganda',
#        'location_oblast Leningradi ', 'location_piirkond Abja mõis',
#        'location_piirkond Haanja', 'location_piirkond Harju tänava haljasala',
#        'location_piirkond Harjumägi', 'location_piirkond Kadrioru park',
#        'location_piirkond Kuramaa', 'location_piirkond Lõuna-Eesti',
#        'location_piirkond Rannamõisa pank',
#        'location_piirkond Seine-Saint-Denis' departemang',
#        'location_piirkond Snelli park',
#        'location_piirkond Tallinna lauluväljak',
#        'location_piirkond Tornide väljak', 'location_piirkond Uus turg',
#        'location_piirkond Vanamõisa mõis', 'location_piirkond Vene turg',
#        'location_piirkond Via Appia pargitee', 'location_poolsaar Krimm',
#        'location_rajoon Abja', 'location_rajoon Lihula',
#        'location_rajoon Neveli', 'location_rand - rannik Pirita rand',
#        'location_riik Kongo', 'location_riik Liivi ordu',
#        'location_riik Preisi ordu', 'location_riik Riia peapiiskopkond',
#        'location_riik Riia peapiiskopkond ja Liivi ordu',
#        'location_riik Riia toomkapiitel ja linn', 'location_riik Saksa',
#        'location_riik Samaniidid', 'location_riik Soome',
#        'location_riik Tartu piiskopkond', 'location_riik Tšehhoslovakkia',
#        'location_riik Uus-Meremaa', 'location_saar Hiiumaa',
#        'location_saar Kassari', 'location_saar Muhu', 'location_saar Naissaar',
#        'location_sadam Tallinna sadam', 'location_soo/raba Keila-Karjaküla',
#        'location_talu Knoobuse', 'location_talu Kuivsaapa',
#        'location_tänav A. Adamsoni', 'location_tänav Alevi',
#        'location_tänav Altmetsa tee', 'location_tänav Endla',
#        'location_tänav Estonia puiestee', 'location_tänav Forelli',
#        'location_tänav G. Otsa', 'location_tänav Harju',
#        'location_tänav Imanta', 'location_tänav J. Poska',
#        'location_tänav J. Vilmsi', 'location_tänav Juhkentali ',
#        'location_tänav Juurdeveo', 'location_tänav K. Türnpuu',
#        'location_tänav Kaarli puiestee', 'location_tänav Kalju',
#        'location_tänav Kaubamaja 1', 'location_tänav Kevade',
#        'location_tänav Koidu', 'location_tänav Kopli',
#        'location_tänav Kullassepa', 'location_tänav Kunderi',
#        'location_tänav Laagna tee', 'location_tänav Lai',
#        'location_tänav Lennuki', 'location_tänav Liivalaia',
#        'location_tänav Loode', 'location_tänav Luise', 'location_tänav Maakri',
#        'location_tänav Malmi', 'location_tänav Maneeži',
#        'location_tänav Mooni', 'location_tänav Mäekalda',
#        'location_tänav Narva maantee', 'location_tänav Nõmme tee',
#        'location_tänav Odra', 'location_tänav P. Süda',
#        'location_tänav Paldiski maantee', 'location_tänav Pikk',
#        'location_tänav Pikk jalg', 'location_tänav Pirita tee',
#        'location_tänav Pronksi', 'location_tänav Pärnu maantee',
#        'location_tänav Rävala pst', 'location_tänav Salme',
#        'location_tänav Suur-Karja', 'location_tänav Sõle',
#        'location_tänav Sõpruse puiestee', 'location_tänav Süda',
#        'location_tänav Tartu maantee', 'location_tänav Tatari',
#        'location_tänav Tehnika', 'location_tänav Toom-Kuninga',
#        'location_tänav Tuvi', 'location_tänav Tööstuse',
#        'location_tänav Uus-Sadama', 'location_tänav Vabaduse väljak',
#        'location_tänav Vabriku', 'location_tänav Vana-Viru',
#        'location_tänav Vene turg', 'location_tänav Viljandi 21',
#        'location_tänav Viru', 'location_tänav Viru väljak',
#        'location_tänav Väike-Ameerika', 'location_tänav Väike-Laagri',
#        'location_tänav Võidu väljak', 'location_tänav Wismari',
#        'location_vabariik Eesti NSV', 'location_vald Helme',
#        'location_vald Kõpu', 'location_vald Rakke', 'location_vald Vigala',
#        'location_väin Vigala vald', 'location_has_a_value',
#        'participant_has_a_value', 'damages_has_a_value',
#        'collection_additional_nr_has_a_value', 'participants_role_has_a_value',
#        'event_type_has_a_value', 'musealia_additional_nr_has_a_value',
#        'is_original_has_a_value', 'class_has_a_value',
#        'museum_abbr_has_a_value', 'color_has_a_value',
#        'collection_mark_has_a_value', 'state_has_a_value',
#        'technique_has_a_value', 'material_has_a_value'],
#       dtype='object')

# %%
#Test 

#print(org_data['location'].isnull().sum())
#data['location_value'] = org_data['location'].apply(lambda x: 0 if pd.isnull(x) else 1)
#print(data['location_value'].value_counts())

# %% [markdown]
# ### Columns to delete

# %%
parish_cols = col_collection(data, 'parish')
data = data.drop(columns= parish_cols)
# Out:
# 3 columns found that start with parish

# %% [markdown]
# ### Saving changes to prep

# %%
data.to_csv('data/prep.csv')
