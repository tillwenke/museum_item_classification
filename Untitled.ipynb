# %%
# Imports
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
data = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
data
# Out:
#      station_id  Aluminium_2019  Aluminium_2020  Ammonium_2019  Ammonium_2020  \
# 0           487             NaN             NaN           0.05           0.05
# 1          1555             NaN             NaN           0.05           0.05
# 2           205             NaN            10.0           0.05           0.24
# 3          1228             NaN             NaN           0.09           0.05
# 4           470             NaN             NaN           0.06           0.05
# ..          ...             ...             ...            ...            ...
# 435         830             NaN             NaN           0.36            NaN
# 436         803             NaN             NaN            NaN            NaN
# 437        1081             NaN             5.0            NaN           0.27
# 438         458             NaN             NaN           0.05           0.05
# 439         725             NaN             NaN           0.05           0.05
#
# ...

# %%
test
# Out:
#      station_id  Aluminium_2019  Aluminium_2020  Ammonium_2019  Ammonium_2020  \
# 0           163             5.0             5.0           0.08           0.08
# 1           167             NaN             NaN           0.08           0.08
# 2           171             NaN             NaN            NaN            NaN
# 3           174             5.0             5.0           0.05           0.09
# 4           178             NaN             NaN           0.05            NaN
# ..          ...             ...             ...            ...            ...
# 184        1941             NaN             NaN           0.05           0.05
# 185        2087             5.0             NaN            NaN            NaN
# 186        2206            27.2            31.1           0.05           0.05
# 187        2303             NaN             5.0            NaN           0.05
# 188        2307             NaN             NaN           0.53            NaN
#
# ...

# %%
museum = pd.read_csv('caps-in-museums-data/train.csv')

# %%
museum
# Out:
#             id                         full_nr  \
# 0       232170  ETMM _ 12150:115 Aj 118:44/M20
# 1      2251378   ETMM _ 12584:19 M 102:1/13:13
# 2      2070466                             NaN
# 3      4085096               ETMM _ Fk 41691/k
# 4      2697904      ETMM _ 9424 Mo 238:1/62:05
# ...        ...                             ...
# 13995  2449318                             NaN
# 13996  2974108        ETMM _ 5429 T 10:3/244:1
# 13997  2068347                             NaN
# 13998  3481436            AM _ 8986:1 G 1678:1
# 13999   216899                             NaN
#
#                                                     name       ks  \
# 0               Kuno Areng, Bremerhaveni Festwoche medal    118.0
# 1       Foto-Villem Kapp,foto pühendusega Armilde M,1937    102.0
# 2                                                    NaN      NaN
# 3      Metspart, Noorsooteater, 1969, osades: Hedvig ...  41691.0
# ...

# %%
for column in museum.columns:
    print(column, museum[column].isna().sum())
# Out:
# id 0
# full_nr 4988
# name 4988
# ks 5184
# material 4988
# commentary 13560
# event_type 4698
# location 12761
# start 8080
# end 12753
# before_Christ 8565
# country_and_unit 4698
# participants_role 7766
# participant 7766
# parish 13986
# text 13771
# class 13771
# technique 8309
# parameter 7429
# unit 7429
# value 7429
# museum_abbr 2
# musealia_mark 3644
# musealia_seria_nr 3990
# musealia_queue_nr 11791
# musealia_additional_nr 13517
# collection_mark 2
# collection_queue_nr 3560
# collection_additional_nr 6494
# element_count 0
# legend 10902
# is_original 2221
# initial_info 12387
# damages 12840
# state 0
# color 13549
# additional_text 10938
# type 0
