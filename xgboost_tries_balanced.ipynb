# %% [markdown]
# # Imports & Settings

# %%
# Imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from deep_translator import GoogleTranslator
import re 
from math import isnan
import wandb
import random
from sklearn.ensemble import RandomForestClassifier

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_seq_items', None)

# %%
# dtype={'type': str} prevents being confused with data type for large data sets
train = pd.read_csv('data/train.csv', index_col='id', dtype={'type': str})
test = pd.read_csv('data/test.csv', index_col='id', dtype={'type': str})
train_translated = pd.read_csv('data/train_translated.csv', dtype={'type': str})
test_translated = pd.read_csv('data/test_translated.csv', index_col='id', dtype={'type': str})
combined_data = pd.read_csv('data/combined_data.csv', index_col='id', dtype={'type': str})
combined_data_translated = pd.read_csv('data/combined_data_translated.csv', index_col='id', dtype={'type': str})
combined_data_fully_translated = pd.read_csv('data/combined_data_fully_translated.csv', index_col='id', dtype={'type': str})
prep = pd.read_csv('data/prep.csv', index_col='id', dtype={'type': str})
test_prep = pd.read_csv('data/test_prepared.csv', index_col='id', dtype={'type': str})
train_prep = pd.read_csv('data/train_prepared.csv', index_col='id', dtype={'type': str})
train_prepROS = pd.read_csv('data/train_prepROS.csv', dtype={'type': str})
train_prepSMOTE = pd.read_csv('data/train_prepSMOTE.csv')

# %% [markdown]
# # xg boost

# %%
import xgboost as xgb
from xgboost import XGBClassifier
# utilities
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %%
dataSMOTE = train_prep.copy()

# %%
y = dataSMOTE.type.astype("category")
# rebalancing cannot deal with string labels
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(y)
y = label_encoder.transform(y)

# %%
featuresSMOTE = dataSMOTE.drop('type', axis=1)
labelsSMOTE = y

# %%
from collections import Counter

X_train, X_test, y_train, y_test = train_test_split(featuresSMOTE, labelsSMOTE, test_size=0.3, random_state=2)

# %%
def strat(data):
    b = Counter(data).values()
    a = Counter(data).keys()
    a = list(a)
    b = list(b)

    for i in range(len(a)):
        if b[i] < 100 :
            b[i] = 100
    return dict(zip(a, b))

# %%
from imblearn.over_sampling import SMOTE, ADASYN
X_resSMOTE, y_resSMOTE = SMOTE(sampling_strategy=strat(y_train), random_state=1).fit_resample(X_train, y_train)
dataSMOTE = X_resSMOTE.copy()
dataSMOTE['type'] = y_resSMOTE
# Out:
# c:\Users\flori\miniconda3\lib\site-packages\imblearn\utils\_validation.py:299: UserWarning: After over-sampling, the number of samples (3747) in class 36 will be larger than the number of samples in the majority class (class #36 -> 2596)
#   warnings.warn(

# %%
bst = XGBClassifier(random_state=0)
# fit model
bst.fit(X_resSMOTE, y_resSMOTE)
# make predictions
preds = bst.predict(X_test)

# %%
val_acc = accuracy_score(y_test, preds)
val_acc
#benchmark: 0.9007142857142857
# Out:
# 0.895

# %%
data.head()
# Out:
#               ks  musealia_seria_nr  musealia_queue_nr  collection_queue_nr  \
# id
# 232170     118.0            12150.0              115.0                 44.0
# 2251378    102.0            12584.0               19.0                  1.0
# 2070466      0.0                0.0                0.0                 52.0
# 4085096  41691.0                0.0                0.0                  0.0
# 2697904    238.0             9424.0                0.0                  1.0
#
#          element_count            type  material_Polish  \
# id
# 232170             1.0           medal                0
# 2251378            1.0           photo                0
# 2070466            1.0           photo                0
# 4085096            1.0  photo negative                0
# 2697904            1.0          letter                0
#
#          material_RC Photo Paper  material_acetate cellulose film  \
# id
# 232170                         0                                0
# 2251378                        0                                0
# 2070466                        0                                0
# 4085096                        0                                0
# 2697904                        0                                0
#
#          material_albumen paper  material_albumin paper  material_aluminium  \
# id
# 232170                        0                       0                   0
# 2251378                       0                       0                   0
# 2070466                       0                       0                   0
# 4085096                       0                       0                   0
# 2697904                       0                       0                   0
#
#          material_artificial material  material_atlas  material_bone  \
# id
# 232170                              0               0              0
# 2251378                             0               0              0
# 2070466                             0               0              0
# 4085096                             0               0              0
# 2697904                             0               0              0
#
#          material_brass  material_bronze  material_canvas  \
# id
# 232170                0                0                0
# 2251378               0                0                0
# 2070466               0                0                0
# 4085096               0                0                0
# 2697904               0                0                0
#
#          material_canvas (type of cloth)  material_cardboard  \
# id
# 232170                                 0                   0
# 2251378                                0                   0
# 2070466                                0                   0
# 4085096                                0                   0
# 2697904                                0                   0
#
#          material_celluloid  material_ceramics  material_charcoal  \
# id
# 232170                    0                  0                  0
# 2251378                   0                  0                  0
# 2070466                   0                  0                  0
# 4085096                   0                  0                  0
# 2697904                   0                  0                  0
#
#          material_chromogen emulsion  material_chromogen paper  material_clay  \
# id
# 232170                             0                         0              0
# 2251378                            0                         0              0
# 2070466                            0                         0              0
# 4085096                            0                         0              0
# 2697904                            0                         0              0
#
#          material_colloid paper  material_colour  material_copper  \
# id
# 232170                        0                0                0
# 2251378                       0                0                0
# 2070466                       0                0                0
# 4085096                       0                0                0
# 2697904                       0                0                0
#
#          material_cotton  material_crystal  material_email  material_emulsion  \
# id
# 232170                 0                 0               0                  0
# 2251378                0                 0               0                  0
# 2070466                0                 0               0                  0
# 4085096                0                 0               0                  0
# 2697904                0                 0               0                  0
#
#          material_feather  material_film  material_film (material)  \
# id
# 232170                  0              0                         0
# 2251378                 0              0                         0
# 2070466                 0              0                         0
# 4085096                 0              0                         0
# 2697904                 0              0                         0
#
#          material_flint  material_glass  material_gold  material_granite  \
# id
# 232170                0               0              0                 0
# 2251378               0               0              0                 0
# 2070466               0               0              0                 0
# 4085096               0               0              0                 0
# 2697904               0               0              0                 0
#
#          material_graphite  material_gypsum  material_handmade paper  \
# id
# 232170                   0                0                        0
# 2251378                  0                0                        0
# 2070466                  0                0                        0
# 4085096                  0                0                        0
# 2697904                  0                0                        0
#
#          material_ink  material_iron  material_linen  material_mascara  \
# id
# 232170              0              0               0                 0
# 2251378             0              0               0                 0
# 2070466             0              0               0                 0
# 4085096             0              0               0                 0
# 2697904             0              0               0                 0
#
#          material_metal  material_moire (clothing variety)  material_movie  \
# id
# 232170                1                                  0               0
# 2251378               0                                  0               0
# 2070466               0                                  0               0
# 4085096               0                                  0               0
# 2697904               0                                  0               0
#
#          material_nan  material_newsprint  material_nitrocellulose film  \
# id
# 232170              0                   0                             0
# 2251378             0                   0                             0
# 2070466             1                   0                             0
# 4085096             0                   0                             0
# 2697904             0                   0                             0
#
#          material_oil paint  material_organic matter  material_paper  \
# id
# 232170                    0                        0               0
# 2251378                   0                        0               0
# 2070466                   0                        0               0
# 4085096                   0                        0               0
# 2697904                   0                        0               1
#
#          material_photo emulsion  material_photo material  \
# id
# 232170                         0                        0
# 2251378                        0                        0
# 2070466                        0                        0
# 4085096                        0                        0
# 2697904                        0                        0
#
#          material_photo paper  material_photo plate  \
# id
# 232170                      0                     0
# 2251378                     0                     0
# 2070466                     0                     0
# 4085096                     0                     0
# 2697904                     0                     0
#
#          material_photographic material  material_plastic  \
# id
# 232170                                0                 0
# 2251378                               1                 0
# 2070466                               0                 0
# 4085096                               1                 0
# 2697904                               0                 0
#
#          material_plastic mass  material_plywood  material_porcelain  \
# id
# 232170                       0                 0                   0
# 2251378                      0                 0                   0
# 2070466                      0                 0                   0
# 4085096                      0                 0                   0
# 2697904                      0                 0                   0
#
#          material_printing ink  material_quartz  material_rubber  \
# id
# 232170                       0                0                0
# 2251378                      0                0                0
# 2070466                      0                0                0
# 4085096                      0                0                0
# 2697904                      0                0                0
#
#          material_salt paper  material_silk  material_silver  \
# id
# 232170                     0              0                0
# 2251378                    0              0                0
# 2070466                    0              0                0
# 4085096                    0              0                0
# 2697904                    0              0                0
#
#          material_silver gelatin emulsion  material_silver gelatin paper  \
# id
# 232170                                  0                              0
# 2251378                                 0                              0
# 2070466                                 0                              0
# 4085096                                 0                              0
# 2697904                                 0                              0
#
#          material_skin  material_stone  material_synthetic fibers  \
# id
# 232170               0               0                          0
# 2251378              0               0                          0
# 2070466              0               0                          0
# 4085096              0               0                          0
# 2697904              0               0                          0
#
#          material_synthetic material  material_textile  material_tin  \
# id
# 232170                             0                 0             0
# 2251378                            0                 0             0
# 2070466                            0                 0             0
# 4085096                            0                 0             0
# 2697904                            0                 0             0
#
#          material_trillion  material_watercolor paint  material_wax  \
# id
# 232170                   0                          0             0
# 2251378                  0                          0             0
# 2070466                  0                          0             0
# 4085096                  0                          0             0
# 2697904                  0                          0             0
#
#          material_white metal  material_wood  material_wood material  \
# id
# 232170                      0              0                       0
# 2251378                     0              0                       0
# 2070466                     0              0                       0
# 4085096                     0              0                       0
# 2697904                     0              0                       0
#
#          technique_(close/together) sewing  technique_addition  \
# id
# 232170                                   0                   0
# 2251378                                  0                   0
# 2070466                                  0                   0
# 4085096                                  0                   0
# 2697904                                  0                   0
#
#          technique_aquatint  technique_ballpoint pen  \
# id
# 232170                    0                        0
# 2251378                   0                        0
# 2070466                   0                        0
# 4085096                   0                        0
# 2697904                   0                        0
#
#          technique_binding techniques  technique_black and white photo  \
# id
# 232170                              0                                0
# 2251378                             0                                0
# 2070466                             0                                0
# 4085096                             0                                0
# 2697904                             0                                0
#
#          technique_black and white photography  technique_carving  \
# id
# 232170                                       0                  0
# 2251378                                      0                  0
# 2070466                                      0                  0
# 4085096                                      0                  0
# 2697904                                      0                  0
#
#          technique_casting  technique_chalk  technique_charcoal  \
# id
# 232170                   0                0                   0
# 2251378                  0                0                   0
# 2070466                  0                0                   0
# 4085096                  0                0                   0
# 2697904                  0                0                   0
#
#          technique_chromogen procedure  technique_collotype  \
# id
# 232170                               0                    0
# 2251378                              0                    0
# 2070466                              0                    0
# 4085096                              0                    0
# 2697904                              0                    0
#
#          technique_color photo  technique_color photography  \
# id
# 232170                       0                            0
# 2251378                      0                            0
# 2070466                      0                            0
# 4085096                      0                            0
# 2697904                      0                            0
#
#          technique_colored chalk  technique_colored pencil  \
# id
# 232170                         0                         0
# 2251378                        0                         0
# 2070466                        0                         0
# 4085096                        0                         0
# 2697904                        0                         0
#
#          technique_coloring  technique_copper engraving  technique_copying  \
# id
# 232170                    0                           0                  0
# 2251378                   0                           0                  0
# 2070466                   0                           0                  0
# 4085096                   0                           0                  0
# 2697904                   0                           0                  0
#
#          technique_crocheting  technique_cuttlefish  \
# id
# 232170                      0                     0
# 2251378                     0                     0
# 2070466                     0                     0
# 4085096                     0                     0
# 2697904                     0                     0
#
#          technique_digital photography  technique_drawing  \
# id
# 232170                               0                  0
# 2251378                              0                  0
# 2070466                              0                  0
# 4085096                              0                  0
# 2697904                              0                  0
#
#          technique_electronic imaging  technique_embroidery  \
# id
# 232170                              0                     0
# 2251378                             0                     0
# 2070466                             0                     0
# 4085096                             0                     0
# 2697904                             0                     0
#
#          technique_enamelling  technique_engraving  technique_etching  \
# id
# 232170                      0                    0                  0
# 2251378                     0                    0                  0
# 2070466                     0                    0                  0
# 4085096                     0                    0                  0
# 2697904                     0                    0                  0
#
#          technique_felt tip pen  technique_glass technology  \
# id
# 232170                        0                           0
# 2251378                       0                           0
# 2070466                       0                           0
# 4085096                       0                           0
# 2697904                       0                           0
#
#          technique_gouache  technique_graphite  technique_handicraft  \
# id
# 232170                   0                   0                     0
# 2251378                  0                   0                     0
# 2070466                  0                   0                     0
# 4085096                  0                   0                     0
# 2697904                  0                   0                     0
#
#          technique_handwriting  technique_ink  technique_ink drawing  \
# id
# 232170                       0              0                      0
# 2251378                      0              0                      0
# 2070466                      0              0                      0
# 4085096                      0              0                      0
# 2697904                      0              0                      0
#
#          technique_kiln ceramics  technique_letterpress with raster cliché  \
# id
# 232170                         0                                         0
# 2251378                        0                                         0
# 2070466                        0                                         0
# 4085096                        0                                         0
# 2697904                        0                                         0
#
#          technique_linocut  technique_lithography  technique_manuscript  \
# id
# 232170                   0                      0                     0
# 2251378                  0                      0                     0
# 2070466                  0                      0                     0
# 4085096                  0                      0                     0
# 2697904                  0                      0                     1
#
#          technique_mascara  technique_mezzotinto  technique_mixed media  \
# id
# 232170                   0                     0                      0
# 2251378                  0                     0                      0
# 2070466                  0                     0                      0
# 4085096                  0                     0                      0
# 2697904                  0                     0                      0
#
#          technique_modeling  technique_molding  technique_monotypy  \
# id
# 232170                    0                  0                   0
# 2251378                   0                  0                   0
# 2070466                   0                  0                   0
# 4085096                   0                  0                   0
# 2697904                   0                  0                   0
#
#          technique_nan  technique_oil  technique_painting  \
# id
# 232170               1              0                   0
# 2251378              1              0                   0
# 2070466              1              0                   0
# 4085096              1              0                   0
# 2697904              0              0                   0
#
#          technique_painting techniques  technique_pannotype  technique_pastel  \
# id
# 232170                               0                    0                 0
# 2251378                              0                    0                 0
# 2070466                              0                    0                 0
# 4085096                              0                    0                 0
# 2697904                              0                    0                 0
#
#          technique_pen  technique_photographic techniques  \
# id
# 232170               0                                  0
# 2251378              0                                  0
# 2070466              0                                  0
# 4085096              0                                  0
# 2697904              0                                  0
#
#          technique_photography  technique_photogravure  \
# id
# 232170                       0                       0
# 2251378                      0                       0
# 2070466                      0                       0
# 4085096                      0                       0
# 2697904                      0                       0
#
#          technique_photolithography  technique_photomechanical printing  \
# id
# 232170                            0                                   0
# 2251378                           0                                   0
# 2070466                           0                                   0
# 4085096                           0                                   0
# 2697904                           0                                   0
#
#          technique_polishing  technique_pressing  technique_printing  \
# id
# 232170                     0                   0                   0
# 2251378                    0                   0                   0
# 2070466                    0                   0                   0
# 4085096                    0                   0                   0
# 2697904                    0                   0                   0
#
#          technique_raster printing  technique_relief  technique_sewing  \
# id
# 232170                           0                 0                 0
# 2251378                          0                 0                 0
# 2070466                          0                 0                 0
# 4085096                          0                 0                 0
# 2697904                          0                 0                 0
#
#          technique_stamping  technique_steel engraving  \
# id
# 232170                    0                          0
# 2251378                   0                          0
# 2070466                   0                          0
# 4085096                   0                          0
# 2697904                   0                          0
#
#          technique_taking pictures  technique_tempera  technique_toning  \
# id
# 232170                           0                  0                 0
# 2251378                          0                  0                 0
# 2070466                          0                  0                 0
# 4085096                          0                  0                 0
# 2697904                          0                  0                 0
#
#          technique_turning  technique_typescript  technique_typing  \
# id
# 232170                   0                     0                 0
# 2251378                  0                     0                 0
# 2070466                  0                     0                 0
# 4085096                  0                     0                 0
# 2697904                  0                     0                 0
#
#          technique_watercolor  technique_wet collodion process  \
# id
# 232170                      0                                0
# 2251378                     0                                0
# 2070466                     0                                0
# 4085096                     0                                0
# 2697904                     0                                0
#
#          technique_wood engraving  technique_woodcut  technique_writing  \
# id
# 232170                          0                  0                  0
# 2251378                         0                  0                  0
# 2070466                         0                  0                  0
# 4085096                         0                  0                  0
# 2697904                         0                  0                  0
#
#          * IN *  amount IN pieces  circumference IN cm  diameter IN cm  \
# id
# 232170      0.0               0.0                  0.0             4.0
# 2251378     0.0               0.0                  0.0             0.0
# 2070466     0.0               0.0                  0.0             0.0
# 4085096     0.0               0.0                  0.0             0.0
# 2697904     0.0               0.0                  0.0             0.0
#
#          distance IN cm  document volume IN pages  height IN cm  \
# id
# 232170              0.0                       0.0           0.0
# 2251378             0.0                       0.0           0.0
# 2070466             0.0                       0.0           0.0
# 4085096             0.0                       0.0           0.0
# 2697904             0.0                       0.0           0.0
#
#          image height IN cm  image width IN cm  length IN cm  \
# id
# 232170                  0.0                0.0           0.0
# 2251378                 0.0                0.0           0.0
# 2070466                 0.0                0.0           0.0
# 4085096                 0.0                0.0           0.0
# 2697904                 0.0                0.0           0.0
#
#          page height IN cm  page width IN cm  paper format IN A6  \
# id
# 232170                 0.0               0.0                 0.0
# 2251378                0.0               0.0                 0.0
# 2070466                0.0               0.0                 0.0
# 4085096                0.0               0.0                 0.0
# 2697904                0.0               0.0                 0.0
#
#          print volume IN pages  size (clothing) IN number  thickness IN cm  \
# id
# 232170                     0.0                        0.0              0.0
# 2251378                    0.0                        0.0              0.0
# 2070466                    0.0                        0.0              0.0
# 4085096                    0.0                        0.0              0.0
# 2697904                    0.0                        0.0              0.0
#
#          time/ duration IN century  volume of the book IN pages  \
# id
# 232170                         0.0                          0.0
# 2251378                        0.0                          0.0
# 2070466                        0.0                          0.0
# 4085096                        0.0                          0.0
# 2697904                        0.0                          0.0
#
#          volume of wood IN dm3  volume of writing IN autograph  weight IN g  \
# id
# 232170                     0.0                             0.0          0.0
# 2251378                    0.0                             0.0          0.0
# 2070466                    0.0                             0.0          0.0
# 4085096                    0.0                             0.0          0.0
# 2697904                    0.0                             0.0          0.0
#
#          width IN cm  film frame IN mm²_height  film frame IN mm²_width  \
# id
# 232170           0.0                       0.0                      0.0
# 2251378          0.0                       0.0                      0.0
# 2070466          0.0                       0.0                      0.0
# 4085096          0.0                      60.0                     60.0
# 2697904          0.0                       0.0                      0.0
#
#          negative format IN mm²_height  negative format IN mm²_width  \
# id
# 232170                             0.0                           0.0
# 2251378                            0.0                           0.0
# 2070466                            0.0                           0.0
# 4085096                            0.0                           0.0
# 2697904                            0.0                           0.0
#
#          photo format IN mm²_height  photo format IN mm²_width  startYear  \
# id
# 232170                          0.0                        0.0       1979
# 2251378                         0.0                        0.0       1938
# 2070466                         0.0                        0.0          0
# 4085096                         0.0                        0.0       1969
# 2697904                         0.0                        0.0          0
#
#          startMonth  startDay  endYear  endMonth  endDay  location_city  \
# id
# 232170            0         0        0         0       0              1
# 2251378           0         0        0         0       0              0
# 2070466           0         0        0         0       0              0
# 4085096           1         1        0         0       0              0
# 2697904           0         0        0         0       0              0
#
#          location_building  location_street  location_country  \
# id
# 232170                   0                0                 0
# 2251378                  0                0                 0
# 2070466                  0                0                 0
# 4085096                  0                0                 0
# 2697904                  0                0                 0
#
#          location_address  state_bad  state_good  state_satisfactory  \
# id
# 232170                  0          0           1                   0
# 2251378                 0          0           1                   0
# 2070466                 0          0           1                   0
# 4085096                 0          0           0                   1
# 2697904                 0          0           0                   1
#
#          state_unspecified  state_very bad  collection_mark_A  \
# id
# 232170                   0               0                  0
# 2251378                  0               0                  0
# 2070466                  0               0                  0
# 4085096                  0               0                  0
# 2697904                  0               0                  0
#
#          collection_mark_Ab  collection_mark_Af  collection_mark_Aj  \
# id
# 232170                    0                   0                   1
# 2251378                   0                   0                   0
# 2070466                   0                   0                   0
# 4085096                   0                   0                   0
# 2697904                   0                   0                   0
#
#          collection_mark_Ar  collection_mark_D  collection_mark_Df  \
# id
# 232170                    0                  0                   0
# 2251378                   0                  0                   0
# 2070466                   0                  0                   0
# 4085096                   0                  0                   0
# 2697904                   0                  0                   0
#
#          collection_mark_Dg  collection_mark_E  collection_mark_F  \
# id
# 232170                    0                  0                  0
# 2251378                   0                  0                  0
# 2070466                   0                  0                  1
# 4085096                   0                  0                  0
# 2697904                   0                  0                  0
#
#          collection_mark_F154  collection_mark_F158  collection_mark_Fk  \
# id
# 232170                      0                     0                   0
# 2251378                     0                     0                   0
# 2070466                     0                     0                   0
# 4085096                     0                     0                   1
# 2697904                     0                     0                   0
#
#          collection_mark_Fm  collection_mark_G  collection_mark_Gk  \
# id
# 232170                    0                  0                   0
# 2251378                   0                  0                   0
# 2070466                   0                  0                   0
# 4085096                   0                  0                   0
# 2697904                   0                  0                   0
#
#          collection_mark_Hp  collection_mark_K  collection_mark_K-  \
# id
# 232170                    0                  0                   0
# 2251378                   0                  0                   0
# 2070466                   0                  0                   0
# 4085096                   0                  0                   0
# 2697904                   0                  0                   0
#
#          collection_mark_M  collection_mark_ML  collection_mark_Mi  \
# id
# 232170                   0                   0                   0
# 2251378                  1                   0                   0
# 2070466                  0                   0                   0
# 4085096                  0                   0                   0
# 2697904                  0                   0                   0
#
#          collection_mark_Mo  collection_mark_N  collection_mark_P  \
# id
# 232170                    0                  0                  0
# 2251378                   0                  0                  0
# 2070466                   0                  0                  0
# 4085096                   0                  0                  0
# 2697904                   1                  0                  0
#
#          collection_mark_P-  collection_mark_PA  collection_mark_PB  \
# id
# 232170                    0                   0                   0
# 2251378                   0                   0                   0
# 2070466                   0                   0                   0
# 4085096                   0                   0                   0
# 2697904                   0                   0                   0
#
#          collection_mark_PK  collection_mark_R-  collection_mark_Sk  \
# id
# 232170                    0                   0                   0
# 2251378                   0                   0                   0
# 2070466                   0                   0                   0
# 4085096                   0                   0                   0
# 2697904                   0                   0                   0
#
#          collection_mark_T  collection_mark_TE  color_beige  color_black  \
# id
# 232170                   0                   0            0            0
# 2251378                  0                   0            0            0
# 2070466                  0                   0            0            0
# 4085096                  0                   0            0            0
# 2697904                  0                   0            0            0
#
#          color_black and white  color_blue  color_brown  color_golden  \
# id
# 232170                       0           0            0             0
# 2251378                      0           0            0             0
# 2070466                      0           0            0             0
# 4085096                      0           0            0             0
# 2697904                      0           0            0             0
#
#          color_green  color_grey  color_monochrome  color_multicolored  \
# id
# 232170             0           1                 0                   0
# 2251378            0           0                 0                   0
# 2070466            0           0                 0                   0
# 4085096            0           0                 0                   0
# 2697904            0           0                 0                   0
#
#          color_orange  color_patterned  color_pink  color_red  color_silver  \
# id
# 232170              0                0           0          0             0
# 2251378             0                0           0          0             0
# 2070466             0                0           0          0             0
# 4085096             0                0           0          0             0
# 2697904             0                0           0          0             0
#
#          color_transparent  color_violet  color_white  color_yellow  \
# id
# 232170                   0             0            0             0
# 2251378                  0             0            0             0
# 2070466                  0             0            0             0
# 4085096                  0             0            0             0
# 2697904                  0             0            0             0
#
#          museum_abbr_AM  museum_abbr_ETMM  class_manufacturer's name  \
# id
# 232170                0                 1                          0
# 2251378               0                 1                          0
# 2070466               1                 0                          0
# 4085096               0                 1                          0
# 2697904               0                 1                          0
#
#          class_name on the source document  is_original_0.0  is_original_1.0  \
# id
# 232170                                   0                0                1
# 2251378                                  0                0                0
# 2070466                                  0                0                0
# 4085096                                  0                0                1
# 2697904                                  0                0                1
#
#          musealia_mark__  before_Christ_no  musealia_additional_nr_01.veebr  \
# id
# 232170                 1                 1                                0
# 2251378                1                 1                                0
# 2070466                0                 0                                0
# 4085096                1                 1                                0
# 2697904                1                 0                                0
#
#          musealia_additional_nr_1  musealia_additional_nr_2  \
# id
# 232170                          0                         0
# 2251378                         0                         0
# 2070466                         0                         0
# 4085096                         0                         0
# 2697904                         0                         0
#
#          musealia_additional_nr_3  musealia_additional_nr_4  \
# id
# 232170                          0                         0
# 2251378                         0                         0
# 2070466                         0                         0
# 4085096                         0                         0
# 2697904                         0                         0
#
#          musealia_additional_nr_5  musealia_additional_nr_6  \
# id
# 232170                          0                         0
# 2251378                         0                         0
# 2070466                         0                         0
# 4085096                         0                         0
# 2697904                         0                         0
#
#          musealia_additional_nr_R  musealia_additional_nr_a  \
# id
# 232170                          0                         0
# 2251378                         0                         0
# 2070466                         0                         0
# 4085096                         0                         0
# 2697904                         0                         0
#
#          musealia_additional_nr_below_thres  country_Ameerika Ühendriigid  \
# id
# 232170                                    0                             0
# 2251378                                   0                             0
# 2070466                                   0                             0
# ...
# 2070466                       0                        0
# 4085096                       0                        0
# 2697904                       0                        0
#
#          location_linnus Toompea  location_määramata Eesti Ajaloomuuseum  \
# id
# 232170                         0                                       0
# 2251378                        0                                       0
# 2070466                        0                                       0
# 4085096                        0                                       0
# 2697904                        0                                       0
#
#          location_määramata Keila-Joa mõis  location_määramata Moskva  \
# id
# 232170                                   0                          0
# 2251378                                  0                          0
# 2070466                                  0                          0
# 4085096                                  0                          0
# 2697904                                  0                          0
#
#          location_määramata Otepää linnus  \
# id
# 232170                                  0
# 2251378                                 0
# 2070466                                 0
# 4085096                                 0
# 2697904                                 0
#
#          location_määramata Vladivostok, Liflandia küla  \
# id
# 232170                                                0
# 2251378                                               0
# 2070466                                               0
# 4085096                                               0
# 2697904                                               0
#
#          location_oblast Karaganda  location_piirkond Vene turg  \
# id
# 232170                           0                            0
# 2251378                          0                            0
# 2070466                          0                            0
# 4085096                          0                            0
# 2697904                          0                            0
#
#          location_piirkond Via Appia pargitee  location_poolsaar Krimm  \
# id
# 232170                                      0                        0
# 2251378                                     0                        0
# 2070466                                     0                        0
# 4085096                                     0                        0
# 2697904                                     0                        0
#
#          location_rajoon Neveli  location_rand - rannik Pirita rand  \
# id
# 232170                        0                                   0
# 2251378                       0                                   0
# 2070466                       0                                   0
# 4085096                       0                                   0
# 2697904                       0                                   0
#
#          location_riik Liivi ordu  \
# id
# 232170                          0
# 2251378                         0
# 2070466                         0
# 4085096                         0
# 2697904                         0
#
#          location_riik Riia peapiiskopkond ja Liivi ordu  \
# id
# 232170                                                 0
# 2251378                                                0
# 2070466                                                0
# 4085096                                                0
# 2697904                                                0
#
#          location_riik Riia toomkapiitel ja linn  location_riik Saksa  \
# id
# 232170                                         0                    0
# 2251378                                        0                    0
# 2070466                                        0                    0
# 4085096                                        0                    0
# 2697904                                        0                    0
#
#          location_riik Soome  location_riik Tartu piiskopkond  \
# id
# 232170                     0                                0
# 2251378                    0                                0
# 2070466                    0                                0
# 4085096                    0                                0
# 2697904                    0                                0
#
#          location_saar Hiiumaa  location_saar Kassari  \
# id
# 232170                       0                      0
# 2251378                      0                      0
# 2070466                      0                      0
# 4085096                      0                      0
# 2697904                      0                      0
#
#          location_sadam Tallinna sadam  location_soo/raba Keila-Karjaküla  \
# id
# 232170                               0                                  0
# 2251378                              0                                  0
# 2070466                              0                                  0
# 4085096                              0                                  0
# 2697904                              0                                  0
#
#          location_tänav Estonia puiestee  location_tänav Forelli  \
# id
# 232170                                 0                       0
# 2251378                                0                       0
# 2070466                                0                       0
# 4085096                                0                       0
# 2697904                                0                       0
#
#          location_tänav Imanta  location_tänav J. Vilmsi  \
# id
# 232170                       0                         0
# 2251378                      0                         0
# 2070466                      0                         0
# 4085096                      0                         0
# 2697904                      0                         0
#
#          location_tänav Juhkentali   location_tänav Kaarli puiestee  \
# id
# 232170                            0                               0
# 2251378                           0                               0
# 2070466                           0                               0
# 4085096                           0                               0
# 2697904                           0                               0
#
#          location_tänav Kalju  location_tänav Kaubamaja 1  \
# id
# 232170                      0                           0
# 2251378                     0                           0
# 2070466                     0                           0
# 4085096                     0                           0
# 2697904                     0                           0
#
#          location_tänav Kopli  location_tänav Kullassepa  \
# id
# 232170                      0                          0
# 2251378                     0                          0
# 2070466                     0                          0
# 4085096                     0                          0
# 2697904                     0                          0
#
#          location_tänav Laagna tee  location_tänav Lai  \
# id
# 232170                           0                   0
# 2251378                          0                   0
# 2070466                          0                   0
# 4085096                          0                   0
# 2697904                          0                   0
#
#          location_tänav Lennuki  location_tänav Liivalaia  \
# id
# 232170                        0                         0
# 2251378                       0                         0
# 2070466                       0                         0
# 4085096                       0                         0
# 2697904                       0                         0
#
#          location_tänav Luise  location_tänav Maakri  location_tänav Mäekalda  \
# id
# 232170                      0                      0                        0
# 2251378                     0                      0                        0
# 2070466                     0                      0                        0
# 4085096                     0                      0                        0
# 2697904                     0                      0                        0
#
#          location_tänav Narva maantee  location_tänav P. Süda  \
# id
# 232170                              0                       0
# 2251378                             0                       0
# 2070466                             0                       0
# 4085096                             0                       0
# 2697904                             0                       0
#
#          location_tänav Paldiski maantee  location_tänav Pirita tee  \
# id
# 232170                                 0                          0
# 2251378                                0                          0
# 2070466                                0                          0
# 4085096                                0                          0
# 2697904                                0                          0
#
#          location_tänav Suur-Karja  location_tänav Sõpruse puiestee  \
# id
# 232170                           0                                0
# 2251378                          0                                0
# 2070466                          0                                0
# 4085096                          0                                0
# 2697904                          0                                0
#
#          location_tänav Tartu maantee  location_tänav Tatari  \
# id
# 232170                              0                      0
# 2251378                             0                      0
# 2070466                             0                      0
# 4085096                             0                      0
# 2697904                             0                      0
#
#          location_tänav Tuvi  location_tänav Vabaduse väljak  \
# id
# 232170                     0                               0
# 2251378                    0                               0
# 2070466                    0                               0
# 4085096                    0                               0
# 2697904                    0                               0
#
#          location_tänav Vabriku  location_tänav Viru  \
# id
# 232170                        0                    0
# 2251378                       0                    0
# 2070466                       0                    0
# 4085096                       0                    0
# 2697904                       0                    0
#
#          location_vabariik Eesti NSV  location_vald Vigala  \
# id
# 232170                             0                     0
# 2251378                            0                     0
# 2070466                            0                     0
# 4085096                            0                     0
# 2697904                            0                     0
#
#          location_has_a_value  participant_has_a_value  damages_has_a_value  \
# id
# 232170                      1                        1                    0
# 2251378                     0                        0                    0
# 2070466                     0                        0                    0
# 4085096                     0                        1                    0
# 2697904                     0                        0                    0
#
#          collection_additional_nr_has_a_value  participants_role_has_a_value  \
# id
# 232170                                      1                              1
# 2251378                                     1                              0
# 2070466                                     0                              0
# 4085096                                     1                              1
# 2697904                                     1                              0
#
#          event_type_has_a_value  musealia_additional_nr_has_a_value  \
# id
# 232170                        1                                   0
# 2251378                       1                                   0
# 2070466                       0                                   0
# 4085096                       1                                   0
# 2697904                       0                                   0
#
#          is_original_has_a_value  class_has_a_value  museum_abbr_has_a_value  \
# id
# 232170                         1                  0                        1
# 2251378                        0                  0                        1
# 2070466                        0                  0                        1
# 4085096                        1                  0                        1
# 2697904                        1                  0                        1
#
#          color_has_a_value  collection_mark_has_a_value  state_has_a_value  \
# id
# 232170                   1                            1                  1
# 2251378                  0                            1                  1
# 2070466                  0                            1                  1
# 4085096                  0                            1                  1
# 2697904                  0                            1                  1
#
#          technique_has_a_value  material_has_a_value
# id
# 232170                       0                     1
# 2251378                      0                     1
# 2070466                      0                     0
# 4085096                      0                     1
# 2697904                      1                     1

# %%
bst.save_model('models/xg/xgboost_0.3_SMOTE100_for_comparison.json')

# %% [markdown]
# # submission from model

# %%
test_set = test_prep.drop('type', axis=1)
results = bst.predict(test_set)
submission = pd.DataFrame({'id': test_set.index ,'type': bst.predict(test_set)})
type_lookup = pd.read_csv('data/type_lookup.csv')
submission = submission.replace(type_lookup.id.to_list(), type_lookup.estonian.to_list())
submission.to_csv('submissions/submission_xgboost_full_SMOTE.csv', index=False)

# %% [markdown]
# # class name mapping

# %%
estonian = train.type.unique()

# %%
english = train_prep.type.unique()

# %%
type_lookup = pd.DataFrame({'estonian': estonian, 'english': english})

# %%
type_lookup = type_lookup.sort_values(by='english')

# %%
type_lookup.reset_index(drop=True, inplace=True)
type_lookup['id'] = type_lookup.index

# %%
type_lookup.to_csv('data/type_lookup.csv')
