# %%
from setup_general import *
# Out:
# /home/till/projects/uni/data science/museum_item_classification/setup_general.py:94: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   combined_intermediate_ready = pd.read_csv('./data/general/combined_intermediate_ready.csv', index_col='id', dtype={'type': str})

# %% [markdown]
# # Original Data

# %%
train.head(1)
# Out:
#                                full_nr  \
# id
# 232170  ETMM _ 12150:115 Aj 118:44/M20
#
#                                             name     ks material commentary  \
# id
# 232170  Kuno Areng, Bremerhaveni Festwoche medal  118.0   metall        NaN
#
#         event_type          location start  end before_Christ  \
# id
# 232170  festivalid  linn Bremerhaven  1979  NaN            ei
#
#        country_and_unit participants_role  participant parish text class  \
# id
# 232170       Saksamaa             osaleja  Areng, Kuno    NaN  NaN   NaN
#
#        technique parameter unit value museum_abbr musealia_mark  \
# id
# 232170       NaN  läbimõõt   cm     4        ETMM             _
#
#         musealia_seria_nr  musealia_queue_nr musealia_additional_nr  \
# id
# 232170            12150.0              115.0                    NaN
#
#        collection_mark  collection_queue_nr collection_additional_nr  \
# id
# 232170              Aj                 44.0                      M20
#
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14000 entries, 0 to 13999
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        14000 non-null  int64
#  1   full_nr                   9012 non-null   object
#  2   name                      9012 non-null   object
#  3   ks                        8816 non-null   float64
#  4   material                  9012 non-null   object
#  5   commentary                440 non-null    object
#  6   event_type                9302 non-null   object
#  7   location                  1239 non-null   object
#  8   start                     5920 non-null   object
#  9   end                       1247 non-null   object
#  10  before_Christ             5435 non-null   object
#  11  country_and_unit          9302 non-null   object
#  12  participants_role         6234 non-null   object
# ...

# %%
train.describe()
# Out:
#                  id             ks  musealia_seria_nr  musealia_queue_nr  \
# count  1.400000e+04    8816.000000       10010.000000        2209.000000
# mean   2.923072e+06    6441.173888       11216.157343         273.129018
# std    8.626119e+05   15473.738824        6850.283512         398.997111
# min    1.956300e+05       1.000000           2.000000           1.000000
# 25%    2.328927e+06      53.000000        7315.000000          25.000000
# 50%    2.870586e+06     416.000000        9951.500000         122.000000
# 75%    3.620546e+06    3517.000000       12582.000000         329.000000
# max    4.322668e+06  123130.000000      111380.000000        4268.000000
#
#        collection_queue_nr  element_count   is_original
# count         10440.000000   14000.000000  11779.000000
# mean            210.702969       1.003071      0.965362
# std             747.038120       0.155585      0.182869
# min               1.000000       1.000000      0.000000
# ...

# %%
train.describe(include=object)
# Out:
#                                full_nr           name material commentary  \
# count                             9012           9012     9012        440
# unique                            9012           7595      108        197
# top     ETMM _ 12150:115 Aj 118:44/M20  Savinõukillud    paber       lakk
# freq                                 1            106     4480         82
#
#           event_type      location start   end before_Christ country_and_unit  \
# count           9302          1239  5920  1247          5435             9302
# unique           477           333  1653   301             1              158
# top     pildistamine  linn Tallinn  1900  1910            ei
# freq             946           302    93    80          5435             5706
#
#        participants_role      participant    parish            text  \
# count               6234             6234        14             229
# unique                45             1848        11             184
# ...

# %%
train.type.value_counts()
# Out:
# foto                             3747
# fotonegatiiv                     2201
# kavand/joonis/eskiis              837
# arheoloogiline leid               789
# plakat                            774
# kava                              771
# kiri                              631
# raamat                            528
# käsikiri                          479
# dokument                          450
# graafika                          225
# noodid                            210
# pitser/templijäljend              196
# münt                              192
# käsikiri, laul/ vokaalmuusika     189
# digitaalne kujutis                187
# postkaart                         156
# väiketrükis                       107
# ajakiri                           104
# ajaleht                            95
# kutse                              93
# medal                              88
# helisalvestis                      74
# telegramm                          70
# käsikiri, muusikateos              63
# ...

# %% [markdown]
# # Translated Data

# %%
train_translated.head(3)
# Out:
#         id                         full_nr  \
# 0   232170  ETMM _ 12150:115 Aj 118:44/M20
# 1  2251378   ETMM _ 12584:19 M 102:1/13:13
# 2  2070466                             NaN
#
#                                                           name     ks  \
# 0                      Kuno Areng, Bremerhaven Festwoche medal  118.0
# 1  Photo-Villem Kapp, photo with dedication to Armilde M, 1937  102.0
# 2                                                          NaN    NaN
#
#                 material commentary                  event_type  \
# 0                  metal        NaN                   festivals
# 1  photographic material        NaN  filmmaking and photography
# 2                    NaN        NaN                         NaN
#
#                   location start  end before_Christ country_and_unit  \
# 0  the city of Bremerhaven  1979  NaN            ei          Germany
# 1                      NaN  1938  NaN            ei              NaN
# ...

# %%
train_translated.type.value_counts()
# Out:
# photo                                           3747
# photo negative                                  2201
# design/drawing/sketch                            837
# archaeological find                              789
# poster                                           774
# plan                                             771
# a letter                                         631
# book                                             528
# manuscript                                       479
# document                                         450
# graphics                                         225
# sheet music                                      210
# there/imprint                                    196
# coin                                             192
# script, song/vocal music                         189
# digital image                                    187
# postcard                                         156
# in small print                                   107
# ...

# %% [markdown]
# # Plot value counts of each feature

# %%
for column in train.columns:
    train[column].value_counts().plot(kind='bar', figsize=(25, 5), title=column)
    plt.show()

# %% [markdown]
# # already classified instances

# %%
keywords = ['medal', 'plakat', 'märkmed', 'maal', 'kleit', 'kava ', 'joonistus', 'graafika', 'dokument',\
'ajakiri', 'telegramm', 'skulptuur', 'raamat', 'postkaart', 'nukk', 'skulptuur', 'käsikiri ', 'kaustik', 'vihik']

#kiri not too save


for word in keywords:
    for i, row in train.iterrows():
        name = row['name']
        if not pd.isnull(name):
            name = str(name).lower()
            if name.startswith(word):
                print(row.type)
# Out:
# fotonegatiiv
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# fotonegatiiv
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# fotonegatiiv
# medal
# medal
# medal
# medal
# medal
# medal
# medal
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# plakat
# ...

# %%
counter = 0

for i, row in train.iterrows():
    if not pd.isnull(row['name']):
        if str(row['name']).lower().startswith(row.type):
            counter += 1
counter
# Out:
# 1741

# %%
counter = 0

for i, row in train.iterrows():
    if not pd.isnull(row['name']):
        if row.type in str(row['name']).lower() and not str(row['name']).lower().startswith(row.type):
            counter += 1
            #print(row.type, row['name'])
counter
# Out:
# 340
