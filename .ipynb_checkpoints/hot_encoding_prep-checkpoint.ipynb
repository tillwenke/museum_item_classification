# %% [markdown]
# # Hot Encoding

# %% [markdown]
# This notebook is used to hot encode our text based categorical features.<br>
# This notebook also includes data minipulation needed before the hot encoding is applied:
# - For some features such as colour, entries are grouped into larger more useful groups
# - Some features have been thresholded so that we can limit the number of additional hot encoded columns
#
# This notebook also includes a section for adjusting the thresholds at a later date

# %% [markdown]
# # Imports & Settings

# %%
# Imports
from setup_general import *

# %% [markdown]
# # Understanding the attributes

# %% [markdown]
# The following columns need to be Hot Encoded:
# - musealia_additional_nr
# - collection_mark
# - state
# - colour -> grouped into base colour groups first
#
# Instead of mapping 0/1
# - museum_abbr
# - class
# - is_orginal
#
# Additionally
# - country
# - city_municipality
# - event_type
# - location - expanded into location_city', 'location_building', 'location_street', 'location_country', 'location_address'
# - before_Christ - rename ei to no
# - country_and_unit - already adapted by till ?
# - participants_role
# - participant
# - parish - v.sparse! almost not worth including
# - collection_additional_nr
# - damages
#
#
# Mapping -> dose value exist yes/no
# - participant
# - musealia_mark? -> simple hot_encode - only has 1 value

# %%
data = prep.copy()

# %%
data.head()
# Out:
#               ks                  event_type          location before_Christ  \
# id
# 232170     118.0                   festivals  linn Bremerhaven            ei
# 2251378    102.0  filmmaking and photography               NaN            ei
# 2070466      NaN                         NaN               NaN           NaN
# 4085096  41691.0                     theater               NaN            ei
# 2697904    238.0                         NaN               NaN           NaN
#
#             participants_role    participant parish class museum_abbr  \
# id
# 232170            participant    Areng, Kuno    NaN   NaN        ETMM
# 2251378                   NaN            NaN    NaN   NaN        ETMM
# 2070466                   NaN            NaN    NaN   NaN          AM
# 4085096  liaison organization  Noorsooteater    NaN   NaN        ETMM
# 2697904                   NaN            NaN    NaN   NaN        ETMM
#
#         musealia_mark  musealia_seria_nr  musealia_queue_nr  \
# id
# ...

# %% [markdown]
# ### Checking and understanding the attrubuites

# %%
data.columns
# Out:
# Index(['ks', 'event_type', 'location', 'before_Christ', 'participants_role',
#        'participant', 'parish', 'class', 'museum_abbr', 'musealia_mark',
#        'musealia_seria_nr', 'musealia_queue_nr', 'musealia_additional_nr',
#        'collection_mark', 'collection_queue_nr', 'collection_additional_nr',
#        'element_count', 'is_original', 'damages', 'state', 'color', 'type',
#        'source', 'city_municipality', 'country', 'material_Polish',
#        'material_RC Photo Paper', 'material_a pearl',
#        'material_acetate cellulose film', 'material_albumen paper',
#        'material_albumin paper', 'material_aluminium', 'material_amber',
#        'material_artificial fiber material', 'material_artificial leather',
#        'material_artificial material', 'material_atlas',
#        'material_ballpoint pen ink', 'material_birch', 'material_bone',
#        'material_brass', 'material_brocade (clothing variety)',
# ...

# %%
data['country'].value_counts()
#start by setting to 2
# Out:
# Eesti                   4257
# Saksamaa                 172
# Vene                     170
# NSVL                     143
# Rootsi                    68
# Soome                     45
# Inglismaa                 42
# Läti                      41
# Ameerika Ühendriigid      38
# Venemaa                   26
# Prantsusmaa               16
# Austria                   14
# Kasahstan                 12
# Kanada                    11
# Itaalia                    9
# Leedu                      9
# Araabia                    8
# Skandinaavia               8
# Poola                      6
# Šveits                     5
# Ukraina                    4
# Austraalia                 4
# Taani                      4
# Ecuador                    3
# Ungari                     3
# Jaapan                     3
# Tshehhi                    3
# Moldaavia                  3
# Siber                      2
# India                      2
# Valgevene                  2
# Rumeenia                   2
# ...

# %%
data['city_municipality'].value_counts()
#Similar to country 
# 48 . with value_counts between 2 - 9 + alot of unique values 
#Threshold set to 2
# Out:
# Tallinn                1320
# Tartu                   185
# Pärnu                    83
# Viljandi                 44
# Haapsalu                 33
# Narva                    29
# Kõmsi                    22
# Kohtla-Järve             18
# Kesklinna                17
# Rakvere                  17
# Harju                    15
# Narva-Jõesuu             11
# Kuressaare               10
# Ida-Viru                  9
# Otepää                    8
# Valga                     7
# Setomaa vald              6
# Võru                      6
# Tartumaa                  6
# Paide                     5
# Aegviidu                  5
# Tapa                      4
# Pärnumaa                  4
# Keila-Joa                 4
# Tootsi                    4
# Käsmu                     4
# Sillamäe                  4
# Kehtna                    3
# Harjumaa Tallinn          3
# Luua                      3
# Lääne-Viru                3
# Kaseküla                  3
# Türi                      3
# ...

# %%
data['event_type'].value_counts()
#Very discriptive feature! - gives a lot of clues to the type
#There are a lot of types - 551 so will need to set a sensible threshold!
#Maybe a threshold of around 30?
#Set to 10 for now
# Out:
# taking pictures                                  1376
# theater performances                             1355
# preparation                                      1201
# theater                                          1106
# culture                                           756
# printing/ publishing                              431
# composing                                         368
# correspondence                                    341
# personal and family life                          287
# music                                             271
# singing parties                                   257
# playwriting                                       253
# photography                                       196
# theater activity                                  149
# military and defense                              138
# appearances                                       128
# street                                            119
# ...

# %%
#location_city', 'location_building', 'location_street', 'location_country', 'location_address'
#Already hot encoded? 
data['location'].value_counts()
#432 diff values!
#set threshold to 10
# Out:
# linn Tallinn                                                            449
# linn Tartu                                                              177
# linn Pärnu                                                              110
# linn Leipzig                                                             61
# linn Moskva                                                              50
# linn Peterburi                                                           42
# riik Saksa                                                               41
# linn Leningrad                                                           25
# linn Berlin                                                              23
# vabariik Eesti NSV                                                       20
# linn Viljandi                                                            20
# linn Berliin                                                             15
# ...

# %%
data['before_Christ'].value_counts()
#Maybe rename ei to no and then hot encode
# Out:
# ei    5435
# no    2391
# Name: before_Christ, dtype: int64

# %%
data['participants_role'].value_counts()
#46 different values in total
#again quite discriptive - gives clues to the type
#some have very high value_counts - maybe set a higher threshold
#Threshold of around 100? -> 10 ok
# Out:
# the author              3182
# liaison organization    1498
# contact person           992
# addressee                374
# participant              318
# author of the text       297
# imagined                 282
# publisher                262
# actor                    203
# photographer             196
# composer                 174
# the issuer               149
# performer                145
# the owner                139
# director                 138
# conductor                113
# a singer                  89
# compiler                  63
# collector                 56
# an artist                 37
# user/owner                35
# maker                     34
# editor                    31
# transferor                27
# printer (maker)           25
# translator                24
# the arranger              23
# musician                  22
# a dancer                  13
# engraver                  12
# device author             11
# co-author                 10
# ...

# %%
data['parish'].value_counts()
#10/12 are unique 
#set Threshold to 2 ? 
#Would probably remove this feature for modelling
# Out:
# Pärnumaa         4
# Harjumaa         4
# Tartumaa         1
# Keila            1
# Jõelähtme        1
# Kuusalu          1
# Jüri             1
# Halliste         1
# Noarootsi        1
# Saaremaa         1
# Rõuge            1
# Pärnu-Jaagupi    1
# Name: parish, dtype: int64

# %%
data['collection_additional_nr'].value_counts()
#4530 different values
#Set Threshold to 30? - only includes the alphabetic vlaues?  or also 100? 
# -> 10
# Out:
# Ar             1131
# T               568
# M               359
# kl              355
# r               341
# k               248
# d                81
# t                43
# a                31
# 01:01            21
# 03:01            19
# 06:01            18
# 14:01            18
# 01:02            17
# 01:05            15
# 02:01            15
# 02:02            14
# 10:01            13
# 01:03            13
# 01:04            12
# T185             12
# 08:01            12
# 03:02            12
# 06:02            12
# 09:01            12
# 05:01            11
# 09:03            11
# 13:02            11
# 34:01:00         11
# 12:01            11
# 01:06            11
# 13:01            11
# 16:02            11
# 51:02:00         10
# 04:02            10
# 18:02            10
# 01.veebr         10
# 07:03            10
# 05:06            10
# 20:01            10
# 11:01            10
# 04:01            10
# 16:01            10
# 04:03            10
# 03:03            10
# ...

# %%
data['damages'].value_counts()
#786 different values
#Some features give clues such as 'The album pages are deformed, there are tears and bruises, the binding holes are broken.'
#Could set Threshold to 15 - 14 new cols -> 10
#Some columns have similar meaning - could group these eg. 'glue marks on the back', 'traces of glue on the back', 'traces of glue'
# Out:
# All right                                                                                                                                                                                                                                                                                                                                                                                                                                                          112
# Cracked                                                                                                                                                                                                                                                                                                                                                                                                                                                            108
# ...

# %%
data['participant'].value_counts()
#2370 - participent names
#Could either set threshold to 100 (-> 50) and have 8 new cols or have a has_value/NaN col?
# Out:
# J. & P. Parikas                                             307
# Teater Estonia                                              284
# Rahvusooper Estonia                                         221
# Leichter, Karl                                              211
# Tamm, Aino                                                  177
# Teater Vanemuine                                            176
# Alla, Armin                                                 137
# Simm, Juhan                                                 107
# Saarne, Henno                                                98
# Teater Endla                                                 84
# Leinus, Karl                                                 84
# Eesti Draamateater                                           77
# Franz, Erika                                                 76
# Kreek, Cyrillus                                              76
# Vilde, Ivar                                                  73
# ...

# %%
data['musealia_mark'].value_counts()
#can hot_encode esaily only has one value!
# Out:
# _    14871
# Name: musealia_mark, dtype: int64

# %%
data['musealia_additional_nr'].value_counts()
#a lot of unique values? - may want to add a threshold
# Out:
# 1           138
# R           106
# 2            63
# 3            34
# 01.veebr     29
# 4            28
# 5            20
# a            15
# 6            12
# 7            10
# 8            10
# 10            9
# 11            8
# b             8
# 9             8
# 20            6
# 15            5
# 16            5
# 24            5
# 13            4
# 27            4
# ab            4
# 32            4
# 23            4
# 21            3
# 86            3
# 14            3
# 28            3
# 197           2
# 38            2
# 128           2
# 12            2
# 103           2
# 142           2
# 25            2
# 36            2
# 44            2
# 30            2
# muusika       2
# 18            2
# 155           2
# 54            2
# 90            2
# 01.apr        2
# a-h           2
# 166           2
# 19            2
# 62            2
# 37            2
# 162           1
# 53            1
# 75            1
# 206           1
# 66            1
# 64            1
# ...

# %%
#data['collection_mark'].value_counts()
#can also probably be used as is

# %%
#data['state'].value_counts() 
#can be hot encoded without threshold

# %%
#data['color'].value_counts()
#decide how to proceed with these? 
#could group by base colour first and then hot encode or use a thresehold of most pop?

# %% [markdown]
# ## Prepping for hot encoding

# %% [markdown]
# ### Colour grouping

# %% [raw]
# value_counts() before grouping:
# multicolored           153
# black and white        146
# black                   75
# white                   50
# blue                    35
# Red                     16
# brown                   15
# violet                  13
# silver                  11
# yellowish white         10
# grey                     8
# light blue               8
# pale yellow              8
# golden                   8
# bluish grey              7
# green                    7
# dark grey                5
# orange                   4
# dark blue                4
# pink                     4
# transparent              4
# light brown              4
# yellow                   4
# light green              3
# brownish black           3
# dark brown               3
# light yellow             3
# light olive green        2
# grey-green               2
# checkered                2
# madara red               2
# dark red                 2
# greyish brown            1
# mauve pink               1
# orange-yellow            1
# bluish white             1
# reddish brown            1
# olive green              1
# purple blue              1
# greyish-olive green      1
# brownish orange          1
# <patterned>              1
# olive brown              1
# beige                    1
# dark green               1
# purple red               1
# greenish blue            1
# greyish blue             1
# pinkish gray             1
# monochrome               1
# yellowish brown          1
# brilliant yellow         1
# striped                  1

# %%
#Grouping colours by their base colour - to avoid too many extra cloumns when hot encoding -> could always reverse this step
#by using  something like data['color'] = combined_data_translated['color'] ?

#The base colours: red, blue, green, grey, yellow, patterned, orange, brown, white, black , pink
#The most common/distingtive stay unchanged


def colour_grouping(x):
    if x in ['madara red', 'dark red', 'purple red', 'Red']:
        return 'red'
    elif x in ['light blue', 'dark blue', 'purple blue', 'greenish blue', 'greyish blue']:
        return 'blue'
    elif x in ['light green', 'light olive green', 'grey-green', 'olive green', 'greyish-olive green', 'dark green']:
        return 'green'
    elif x in ['bluish grey', 'dark grey', 'pinkish gray']:
        return 'grey'
    elif x in ['pale yellow', 'light yellow', 'orange-yellow', 'brilliant yellow']:
        return 'yellow'
    elif x in ['brownish orange']:
        return 'orange'
    elif x in ['light brown', 'dark brown', 'greyish brown', 'reddish brown', 'olive brown', 'yellowish brown']:
        return 'brown'
    elif x in ['yellowish white', 'bluish white']:
        return 'white'
    elif x in ['brownish black']:
        return 'black'
    elif x in ['mauve pink']:
        return 'pink'
    elif x in ['<patterned>', 'striped', 'checkered']:
        return 'patterned'
    else:
        return x

# %%
#apply colour_grouping to the dataset
data['color'] = data['color'].apply(colour_grouping)

# %%
#value_counts() after
data['color'].value_counts()
# Out:
# multicolored       153
# black and white    146
# black               78
# white               61
# blue                50
# brown               26
# grey                21
# red                 21
# yellow              17
# green               17
# violet              13
# silver              11
# golden               8
# pink                 5
# orange               5
# transparent          4
# patterned            4
# monochrome           1
# beige                1
# Name: color, dtype: int64

# %% [markdown]
# ### before_Christ prep

# %%
data['before_Christ'].value_counts()
#5435 values for 'ei' and 2391 values for 'no', ei = no
#Rename both to 'no'
# Out:
# ei    5435
# no    2391
# Name: before_Christ, dtype: int64

# %%
data['before_Christ'] = data['before_Christ'].replace('ei', 'no')

# %%
data['before_Christ'].value_counts()
# Out:
# no    7826
# Name: before_Christ, dtype: int64

# %% [markdown]
# ### Threshold

# %% [markdown]
# Define a function that:
# - goes through the value_counts and selects all the values below the threshold
# - labels these as 'below_tres' and groups these together
#
# So that during the hot_encoding we only have columns for values that appear at least as often as the threshold

# %% [markdown]
# ### Threshold Function

# %%
def group_under_threshold(data, col, threshold):
    values_to_group = []
    for idx, name in enumerate(data[col].value_counts().index):
        if(data[col].value_counts()[idx] <= threshold):
            values_to_group.append(name)
    print(values_to_group)
    return data[col].apply(lambda x: 'below_thres' if (x in values_to_group) else x)

# %% [markdown]
# ### Apply to columns

# %% [markdown]
# ##### musealia_additional_nr

# %% [raw]
# Before appling the grouping
# data['musealia_additional_nr'].value_counts()
#
# 1           138
# R           106
# 2            63
# 3            34
# 01.veebr     29
# 4            28
# 5            20
# a            15
# 6            12
# 7            10
# 8            10
# 10            9
# 11            8
# b             8
# 9             8
# 20            6
# 15            5
# 16            5
# 24            5
# 13            4
# 27            4
# ab            4
# 32            4
# 23            4
# 21            3
# 86            3
# 14            3
# 28            3
# 197           2
# 38            2
# 128           2
# 12            2
# 103           2
# 142           2
# 25            2
# 36            2
# 44            2
# 30            2
# muusika       2
# 18            2
# 155           2
# 54            2
# 90            2
# 01.apr        2
# a-h           2
# 166           2
# 19            2
# 62            2
# 37            2
# 162           1
# 53            1
# 75            1
# 206           1
# 66            1
# 64            1
# 31            1
# c             1
# a-b           1
# 01.juuli      1
# 77            1
# 29            1
# 40            1
# 188           1
# 139           1
# 119           1
# j             1
# 34            1
# 33            1
# 221           1
# 144           1
# 127           1
# 22            1
# 145           1
# 87            1
# a-k           1
# 41            1
# 220           1
# 110           1
# 89            1
# 57            1
# 126           1
# 143           1
# 190           1
# 125           1
# 168           1
# 17            1
# 39            1
# 241           1
# 138           1
# 26            1
# a-i           1
# 121           1
# 50            1
# c32           1
# 84            1
# 65            1
# a-d           1
# c19           1
# 47            1
# 293           1
# 231           1
# 72            1
# 154           1
# 83            1
# 73            1
# 185           1
# 217           1
# 59            1
# 303           1
# 132           1
# 94            1
# 51            1
# 109           1
# 151           1
# 63            1
# 49            1
# 116           1
# 105           1
# 156           1
# 136           1
# 104           1
# 113           1
# Name: musealia_additional_nr, dtype: int64

# %%
#Threshold 10
data['musealia_additional_nr'] = group_under_threshold(data, 'musealia_additional_nr', 10)
# Out:
# ['7', '8', '10', '11', 'b', '9', '20', '15', '16', '24', '13', '27', 'ab', '32', '23', '21', '86', '14', '28', '197', '38', '128', '12', '103', '142', '25', '36', '44', '30', 'muusika', '18', '155', '54', '90', '01.apr', 'a-h', '166', '19', '62', '37', '162', '53', '75', '206', '66', '64', '31', 'c', 'a-b', '01.juuli', '77', '29', '40', '188', '139', '119', 'j', '34', '33', '221', '144', '127', '22', '145', '87', 'a-k', '41', '220', '110', '89', '57', '126', '143', '190', '125', '168', '17', '39', '241', '138', '26', 'a-i', '121', '50', 'c32', '84', '65', 'a-d', 'c19', '47', '293', '231', '72', '154', '83', '73', '185', '217', '59', '303', '132', '94', '51', '109', '151', '63', '49', '116', '105', '156', '136', '104', '113']

# %%
data['musealia_additional_nr'].value_counts()
# Out:
# below_thres    221
# 1              138
# R              106
# 2               63
# 3               34
# 01.veebr        29
# 4               28
# 5               20
# a               15
# 6               12
# Name: musealia_additional_nr, dtype: int64

# %% [markdown]
# ##### country

# %%
#Threshold = 10
data['country'] = group_under_threshold(data, 'country', 10)
# Out:
# ['Itaalia', 'Leedu', 'Araabia', 'Skandinaavia', 'Poola', 'Šveits', 'Ukraina', 'Austraalia', 'Taani', 'Ecuador', 'Ungari', 'Jaapan', 'Tshehhi', 'Moldaavia', 'Siber', 'India', 'Valgevene', 'Rumeenia', 'Liivimaa', 'Bulgaaria', 'Abhaasia', 'Iirimaa', 'Euroopa', 'Shveitsi', 'Holland', 'Armeenia', 'Aafrika', 'Korea', 'Hispaania', 'Türgi', 'Gruusia', 'Nepaal', 'Portugal', 'Norra', 'Hiina', 'Usbeki', 'Brasiilia', 'Belgia']

# %% [markdown]
# ##### city_municipality

# %%
#Threshold = 5 - could up to 10!
data['city_municipality'] = group_under_threshold(data, 'city_municipality', 5)
# Out:
# ['Paide', 'Aegviidu', 'Tapa', 'Pärnumaa', 'Keila-Joa', 'Tootsi', 'Käsmu', 'Sillamäe', 'Kehtna', 'Harjumaa Tallinn', 'Luua', 'Lääne-Viru', 'Kaseküla', 'Türi', 'Martna', 'Põlva', 'Halliste', 'Järvakandi', 'Alatskivi', 'Paldiski', 'Vigala', 'Vändra', 'Lääne', 'Meleski', 'Klooga', 'Rannamõisa', 'Jõhvi', 'Viru-Jaagupi', 'Saaremaa', 'Järva', 'Väike-Maarja', 'Keila', 'Lõhavere', 'Võhma', 'Ambla', 'Haabersti', 'Põltsamaa', 'Kunda', 'Pirita', 'Tarvastu', 'Kirbla', 'Tamsalu', 'Abja-Vanamõisa', 'Virtsu', 'Sangaste', 'Lohusuu', 'Tõhela', 'Kurgja', 'Taagepera', 'Eidapere', 'Tori', 'Noarootsi Noarootsi', 'Olustvere', 'Lohusalu', 'Rõuge Võru', 'Türisalu', 'Võsu', 'Kallavere', 'Hüti', 'Tõrva', 'Heimtali', 'Paju', 'Saarde', 'Kõpu', 'Õisu', 'Vana-Kariste', 'Kihelkonna', 'Pärnu-Jaagupi', 'Kiviõli', 'Värska', 'Kabala', 'Laimjala', 'Toila', 'Ridala', 'Saareküla', 'Kaberneeme', 'Raasiku', 'Tartumaa Tartu', 'Avinurme', 'Saue', 'Roela', 'Sindi', 'Harku', 'Muhu', 'Puka', 'Viimsi', 'Laulasmaa', 'Maardu', 'Jõe
# ...

# %% [markdown]
# ###### event type

# %%
#Threshold = 10 - could up to 30
data['event_type'] = group_under_threshold(data, 'event_type', 10)
# Out:
# ['sports', 'poetry', 'publishing', 'ballet performances', 'drawing', 'industrial production', 'museums', 'production processes', 'celebrations', 'sculpture (fine art)', 'educational institutions', 'folk clothes', 'art/architecture', 'trade unions', 'restaurants', 'wood and paper industry', 'portrait of a woman', 'concert acts', 'city life', 'economy', 'music theory', 'singers', 'advertising', 'cafes', 'working', 'botany', 'farm buildings', 'military action', 'expeditions', 'film production', 'festivals', 'national military units', 'holidays and anniversaries', 'planned economy', 'ethnography', 'guest performances', 'tourism', 'science', 'wedding', 'fortresses', 'travel albums/diaries', 'rail transport', 'musicals', 'anatomy', 'death', 'cultural days', 'monasteries', 'meeting', 'glass art', 'popular music', 'festive receptions', 'labor movement', 'women', 'philology', 'symphony orchestras', 'industrial buildings', "women's clothing", 'urban construction', 'literary history', 'teaching
# ...

# %% [markdown]
# ###### participants_role

# %%
#Threshold = 10 - could up to 100 or at least 20
data['participants_role'] = group_under_threshold(data, 'participants_role', 10)
# Out:
# ['co-author', 'owner/authorizer', 'an architect', 'playwright', 'receiver', 'from the libretto', 'instructor', 'designer/ shaper', 'documenter', 'the interviewer', 'the interviewee', 'reads the text', 'copier', 'discoverer/finder', 'designer']

# %% [markdown]
# ###### parish

# %%
#Not sure it is worth it! - could even just hot encode as is
data['parish'] = group_under_threshold(data, 'parish', 2)
# Out:
# ['Tartumaa', 'Keila', 'Jõelähtme', 'Kuusalu', 'Jüri', 'Halliste', 'Noarootsi', 'Saaremaa', 'Rõuge', 'Pärnu-Jaagupi']

# %% [markdown]
# ###### collection_additional_nr

# %%
#Threshold = 10
data['collection_additional_nr'] = group_under_threshold(data, 'collection_additional_nr', 10)
# Out:
# ['51:02:00', '04:02', '18:02', '01.veebr', '07:03', '05:06', '20:01', '11:01', '04:01', '16:01', '04:03', '03:03', '06:05', '05:08', '25:03:00', '38:01:00', '19:01', '05:02', '15:01', '42:01:00', '02:04', '13:03', '50:01:00', '2', '17:01', '12:03', '07:02', '09:02', '11:03', '14:02', '18:01', 'b', '30:01:00', '40:01:00', '07:01', '54:01:00', '48:02:00', '31:01:00', '27:02:00', '111:01:00', '43:01:00', 'M112', '44:01:00', '21:03', '35:02:00', '08:06', '12:07', '10:03', '33:01:00', '19:05', '10:02', '45:01:00', '47:01:00', '23:01', '01:07', '20:03', '18:03', '19:03', '20:02', '09:06', '24:02:00', '24', '01:15', '17:02', '03:04', '15:03', '75:01:00', '27:01:00', '25:07:00', '24:01:00', '39:01:00', '14:03', '52:01:00', '20:05', '26:03:00', '20:08', '06:04', '03:06', '11:02', '09:04', '12:02', '14:05', '02:08', '15:02', '26:01:00', '43:05:00', '09:11', '06:22', '06:03', '05:03', '06:07', '05:07', '28:01:00', '45:04:00', '08:02', '10:05', '29:04:00', '02:03', '06:12', '29:16:00', '57:02:00
# ...

# %% [markdown]
# ###### damages

# %%
#Threshold = 15
#may want to do a little grouping first 
data['damages'] = group_under_threshold(data, 'damages', 15)
# Out:
# ['slightly soiled', 'With broken lines', 'wrinkled, dirty', 'silver mirror', 'A little worn', 'Silver mirror on the edges', 'yellowed, wrinkled', 'Worn out.', 'cracked\r\ncracked', 'Worn out', 'yellowed, worn', 'slightly yellowed', 'yellowed, worn, torn', 'dirty, tears', 'yellowed, stained', 'slightly curved, slightly curved', 'silver mirror at the edges', 'Yellowed.', 'torn', "there isn't", 'ok', 'stains', 'paper damage', 'fragment, fragment', 'yellowed, mottled', 'Glass dirty, silver mirror at the edges', 'edges slightly soiled', 'wrinkle, soot damage', 'moisture damage', 'Sulfurization', 'Lightly soiled', 'corners dirty', 'yellowed, moisture stains', 'tears', 'a little dirty', 'Little dust under the cover glass.', 'the photo is pasted in the album, the photo paper has become wavy in places., the photo has been pasted in the album, the photo paper has become wavy in places.', 'adhesive damage', 'Slight soiling at the edges of the album page.', 'covered with brown spots', 'dirty, wr
# ...

# %% [markdown]
# ###### participant

# %%
#Threshold = 10 - could definiely up this threshold!
data['participant'] = group_under_threshold(data, 'participant', 10)
# Out:
# ['Tšaikovski, Pjotr', 'Vaarman, Els', 'Kasemets, Anton', 'Mattiisen, Alo', 'Krause, Wilhelm', 'Kõrver, Boris', 'Lilje, Peeter', 'Leet, Mare', 'Võrk, Enn', 'Kütt, Laine', 'Mildeberg, Aleksander', 'A.M. Lutheri vabrik', 'Riia Heliplaadivabrik Melodija', 'Mõtus, Tiit', 'Teater NO99', 'Voolmaa (Voolman), Hans', 'Raudsepp, Hugo', 'Rannap, Rein', 'Eesti Raamat', 'Blankenfeld, Johannes V', 'Adelheid', 'Karlson, Ernst', 'Kitzberg, August', 'Klas, Anna', 'Lauter, Ants', 'Konrad II', 'Tallinna Konservatoorium', 'Galina Tšernjavskaja balletistuudio', 'Vene Teater', 'Eesti Lauljate Liit', 'Unt, Mati', 'Eesti Riiklik Teatriinstituut', 'Karmi, Väino', 'Vain, Evald', 'Reining, Eduard', 'Peep, Ao', 'Ird, Kaarel', 'Tamberg, Eino', 'Tarbeklaas', 'Loik, Valerian', 'Tondu, Toomas', 'Verlin, Lembit', 'Liives, Ardi', 'Ploom, Rein', 'Vennad Christin', 'Vilde, Eduard', 'Peil, Voldemar', 'Eesti Riiklik Kirjastus', 'Poland, Eduard', 'Vare', 'Marist, Aario', 'Küla, Mari-Liis', 'Järvet, Jüri', 'Kull, Raimund', 
# ...

# %% [markdown]
# ## Run hot encoding

# %%
data.columns
# Out:
# Index(['ks', 'event_type', 'location', 'before_Christ', 'participants_role',
#        'participant', 'parish', 'class', 'museum_abbr', 'musealia_mark',
#        'musealia_seria_nr', 'musealia_queue_nr', 'musealia_additional_nr',
#        'collection_mark', 'collection_queue_nr', 'collection_additional_nr',
#        'element_count', 'is_original', 'damages', 'state', 'color', 'type',
#        'source', 'city_municipality', 'country', 'material_Polish',
#        'material_RC Photo Paper', 'material_a pearl',
#        'material_acetate cellulose film', 'material_albumen paper',
#        'material_albumin paper', 'material_aluminium', 'material_amber',
#        'material_artificial fiber material', 'material_artificial leather',
#        'material_artificial material', 'material_atlas',
#        'material_ballpoint pen ink', 'material_birch', 'material_bone',
#        'material_brass', 'material_brocade (clothing variety)',
# ...

# %%
#For columns without thresholding
columns = ['state', 'collection_mark', 'color', 'museum_abbr', 'class', 'is_original', 'musealia_mark', 'before_Christ']
data_dum = pd.get_dummies(data, columns = columns)

# %%
data_dum.head()
# Out:
#               ks                  event_type          location  \
# id
# 232170     118.0                 below_thres  linn Bremerhaven
# 2251378    102.0  filmmaking and photography               NaN
# 2070466      NaN                         NaN               NaN
# 4085096  41691.0                     theater               NaN
# 2697904    238.0                         NaN               NaN
#
#             participants_role    participant parish  musealia_seria_nr  \
# id
# 232170            participant    Areng, Kuno    NaN            12150.0
# 2251378                   NaN            NaN    NaN            12584.0
# 2070466                   NaN            NaN    NaN                NaN
# 4085096  liaison organization  Noorsooteater    NaN                NaN
# 2697904                   NaN            NaN    NaN             9424.0
#
#          musealia_queue_nr musealia_additional_nr  collection_queue_nr  \
# id
# ...

# %%
data_dum.columns
# Out:
# Index(['ks', 'event_type', 'location', 'participants_role', 'participant',
#        'parish', 'musealia_seria_nr', 'musealia_queue_nr',
#        'musealia_additional_nr', 'collection_queue_nr',
#        'collection_additional_nr', 'element_count', 'damages', 'type',
#        'source', 'city_municipality', 'country', 'material_Polish',
#        'material_RC Photo Paper', 'material_a pearl',
#        'material_acetate cellulose film', 'material_albumen paper',
#        'material_albumin paper', 'material_aluminium', 'material_amber',
#        'material_artificial fiber material', 'material_artificial leather',
#        'material_artificial material', 'material_atlas',
#        'material_ballpoint pen ink', 'material_birch', 'material_bone',
#        'material_brass', 'material_brocade (clothing variety)',
#        'material_bronze', 'material_canvas', 'material_canvas (type of cloth)',
#        'material_cardboard', 'material_cast iron', 'material_celluloid',
# ...

# %%
#For columns with thresholding
thres_columns = ['musealia_additional_nr', 'country', 'city_municipality', 'event_type', 'participants_role', 'parish', 'collection_additional_nr', 'damages', 'participant', 'location']
data_dum = pd.get_dummies(data_dum, columns = thres_columns)

# %%
data_dum.head()
# Out:
#               ks  musealia_seria_nr  musealia_queue_nr  collection_queue_nr  \
# id
# 232170     118.0            12150.0              115.0                 44.0
# 2251378    102.0            12584.0               19.0                  1.0
# 2070466      NaN                NaN                NaN                 52.0
# 4085096  41691.0                NaN                NaN                  NaN
# 2697904    238.0             9424.0                NaN                  1.0
#
#          element_count            type source  material_Polish  \
# id
# 232170             1.0           medal  train                0
# 2251378            1.0           photo  train                0
# 2070466            1.0           photo  train                0
# 4085096            1.0  photo negative  train                0
# 2697904            1.0          letter  train                0
#
#          material_RC Photo Paper  material_a pearl  \
# id
# 232170                         0                 0
# ...

# %%
data_dum.columns
# Out:
# Index(['ks', 'musealia_seria_nr', 'musealia_queue_nr', 'collection_queue_nr',
#        'element_count', 'type', 'source', 'material_Polish',
#        'material_RC Photo Paper', 'material_a pearl',
#        'material_acetate cellulose film', 'material_albumen paper',
#        'material_albumin paper', 'material_aluminium', 'material_amber',
#        'material_artificial fiber material', 'material_artificial leather',
#        'material_artificial material', 'material_atlas',
#        'material_ballpoint pen ink', 'material_birch', 'material_bone',
#        'material_brass', 'material_brocade (clothing variety)',
#        'material_bronze', 'material_canvas', 'material_canvas (type of cloth)',
#        'material_cardboard', 'material_cast iron', 'material_celluloid',
#        'material_ceramics', 'material_chalk', 'material_chamois leather',
#        'material_chamotte', 'material_charcoal', 'material_chromogen emulsion',
#        'material_chromogen paper', 'material_clay',
# ...

# %% [markdown]
# ## Save changes to prep

# %%
data_dum.to_csv('data/prep.csv')

# %%
#check
data2 = pd.read_csv('data/prep.csv', index_col='id', dtype={'type': str})
# Out:
# C:\Users\daria\AppData\Local\Temp\ipykernel_1180\1430599759.py:1: DtypeWarning: Columns (226,235) have mixed types. Specify dtype option on import or set low_memory=False.
#   data2 = pd.read_csv('data/prep.csv', index_col='id', dtype={'type': str})

# %%
data2.columns
# Out:
# Index(['ks', 'musealia_seria_nr', 'musealia_queue_nr', 'collection_queue_nr',
#        'element_count', 'type', 'source', 'material_Polish',
#        'material_RC Photo Paper', 'material_a pearl',
#        'material_acetate cellulose film', 'material_albumen paper',
#        'material_albumin paper', 'material_aluminium', 'material_amber',
#        'material_artificial fiber material', 'material_artificial leather',
#        'material_artificial material', 'material_atlas',
#        'material_ballpoint pen ink', 'material_birch', 'material_bone',
#        'material_brass', 'material_brocade (clothing variety)',
#        'material_bronze', 'material_canvas', 'material_canvas (type of cloth)',
#        'material_cardboard', 'material_cast iron', 'material_celluloid',
#        'material_ceramics', 'material_chalk', 'material_chamois leather',
#        'material_chamotte', 'material_charcoal', 'material_chromogen emulsion',
#        'material_chromogen paper', 'material_clay',
# ...

# %% [markdown]
# # Re-hot encoding

# %% [markdown]
# Used for adjusting the thresholds after the hot encoding has already occured

# %% [markdown]
# ## Functions

# %%
# drop old hot encoded columns swap out for orginal, re-do 
#data[str(col_start)+'_has_a_value'] = 0

def re_threshold(data, org_data, col_start, new_thres):
    #remove old hot encoded columns
    cols = []
    for c in data.columns:
        if (c == str(col_start)+'_has_a_value'):
            continue
        elif (c.startswith(col_start)):
            cols.append(c)
    data = data.drop(columns = cols)
    
    #replace with orginal feature columns - pre manipulation
    data[col_start] = org_data[col_start]
    
    #apply new threshold:
    data[col_start] = group_under_threshold(data, col_start, new_thres)
    return data

#outside function
#data[col_start] = re_threshold(...)
#then hot encode all needed columns

# %% [markdown]
# # Apply to code - higher thresholds

# %%
#make copies of needed data
data = prep.copy()
org_data = combined_data_fully_translated.copy()

# %% [markdown]
# New thresholds:
# - 'country' : 2 -> 10 (new columns only added after manipulation)
# - 'city_municipality: 5 -> 10 ('')
# - 'event_type': 10 -> 20/30
# - 'location': 10 -> 20
# - 'participant_role': 10 -> 100
# - 'collection_additional_nr': 10 -> 30
# - 'damages': 15 -> 30
# - 'participant': 10 -> 100
# - 'musealia_additional_nr': -> 10
# - 'material': -> 50
# - 'technique': -> 50

# %%
#apply new threshols
data = re_threshold(data, org_data, 'event_type', 30)
data = re_threshold(data, org_data, 'location', 20)
data = re_threshold(data, org_data, 'collection_additional_nr', 30)
data = re_threshold(data, org_data, 'damages', 30)
data = re_threshold(data, org_data, 'participant', 100)
data = re_threshold(data, org_data, 'musealia_additional_nr', 10)
data = re_threshold(data, org_data, 'participants_role', 100)
data = re_threshold(data, org_data, 'material', 50)
data = re_threshold(data, org_data, 'technique', 50)
# Out:
# ['graphics (visual arts)', 'food trade', 'theater education', 'metal art', 'birthdays', 'writing', 'collecting/finding', 'politics', 'industry', 'music festivals', 'literature', 'ethnology', 'travelling', 'mixed choirs', 'drafting', 'solo song', 'Agriculture', 'music education', 'archaeological excavations', 'history', 'photos (works)', 'male choirs', 'arrangement', 'memories', 'group portrait', 'funeral', 'religion and beliefs', 'archaeology', 'cultural history', 'rest/ free time', 'competitions - inspections', 'manuscript preparation', 'ballet', 'theater criticism', 'bombing', 'new year/ gums', 'biographies', 'dancing', 'landscapes', 'doing choral singing', 'reference literature', 'army', 'school life', 'filming', 'operettas', 'information storage', 'films (works)', 'family', 'lifestyle/living situation', 'dance parties', 'trading/shop', 'propaganda/campaign', 'music history', 'making by hand', 'telegraph', 'pedagogy', 'furniture industry', 'collective farms/cooperatives', 'ceramic
# ...

# %%
data.columns
# Out:
# Index(['ks', 'musealia_seria_nr', 'musealia_queue_nr', 'collection_queue_nr',
#        'element_count', 'type', 'source', '* IN *', 'amount IN pieces',
#        'circumference IN cm', 'diameter IN cm', 'distance IN cm',
#        'document volume IN pages', 'height IN cm', 'image height IN cm',
#        'image width IN cm', 'length IN cm', 'page height IN cm',
#        'page width IN cm', 'paper format IN A6', 'print volume IN pages',
#        'size (clothing) IN number', 'thickness IN cm',
#        'time/ duration IN century', 'volume of the book IN pages',
#        'volume of wood IN dm3', 'volume of writing IN autograph',
#        'weight IN g', 'width IN cm', 'film frame IN mm²_height',
#        'film frame IN mm²_width', 'negative format IN mm²_height',
#        'negative format IN mm²_width', 'photo format IN mm²_height',
#        'photo format IN mm²_width', 'startYear', 'startMonth', 'startDay',
#        'endYear', 'endMonth', 'endDay', 'state_bad', 'state_good',
# ...

# %%
#re run hot encoding
thres_columns = ['musealia_additional_nr', 'event_type', 'participants_role', 'collection_additional_nr', 'damages', 'participant', 'location', 'material', 'technique']
data_dum = pd.get_dummies(data, columns = thres_columns)

# %%
data_dum.columns
# Out:
# Index(['ks', 'musealia_seria_nr', 'musealia_queue_nr', 'collection_queue_nr',
#        'element_count', 'type', 'source', '* IN *', 'amount IN pieces',
#        'circumference IN cm', 'diameter IN cm', 'distance IN cm',
#        'document volume IN pages', 'height IN cm', 'image height IN cm',
#        'image width IN cm', 'length IN cm', 'page height IN cm',
#        'page width IN cm', 'paper format IN A6', 'print volume IN pages',
#        'size (clothing) IN number', 'thickness IN cm',
#        'time/ duration IN century', 'volume of the book IN pages',
#        'volume of wood IN dm3', 'volume of writing IN autograph',
#        'weight IN g', 'width IN cm', 'film frame IN mm²_height',
#        'film frame IN mm²_width', 'negative format IN mm²_height',
#        'negative format IN mm²_width', 'photo format IN mm²_height',
#        'photo format IN mm²_width', 'startYear', 'startMonth', 'startDay',
#        'endYear', 'endMonth', 'endDay', 'state_bad', 'state_good',
# ...

# %%
#Save to csv:
data_dum.to_csv('data/prep_high_thres.csv')

# %% [markdown]
# ## Apply to features - lower threshold

# %%
data = prep.copy()
org_data = combined_data_fully_translated.copy()

# %%
data = re_threshold(data, org_data, 'event_type', 2)
data = re_threshold(data, org_data, 'location', 2)
data = re_threshold(data, org_data, 'collection_additional_nr', 2)
data = re_threshold(data, org_data, 'damages', 2)
data = re_threshold(data, org_data, 'participant', 2)
data = re_threshold(data, org_data, 'musealia_additional_nr', 2)
data = re_threshold(data, org_data, 'participants_role', 2)
data = re_threshold(data, org_data, 'material', 1)
data = re_threshold(data, org_data, 'technique', 1)
# Out:
# ['playing', 'animals', 'processions', 'Congress', 'childhood', 'rationalization', 'smoking', 'student life', 'entrepreneurship', 'grief', 'apartment buildings', 'sports competitions', 'military training', 'numismatics', 'cemeteries', 'farming', 'radio theaters', 'applied art', 'party activity', 'ready', 'career', 'kindergartens', 'clay works', 'memorial exhibitions', 'war memorials', '<collection activity>', 'photojournalism', 'general', 'educational buildings', 'slaughterhouses', 'dance history', 'religion and related disciplines', 'sanatoriums', 'steamships', 'Christianity', 'club activities', 'folk music groups', 'music reviews', 'Lakes', 'peat industry', 'language', 'trade regulation', 'psychology', 'funeral supplies', 'repression', 'election campaigns', 'town halls', 'establishing peace', 'church history', 'folklore', 'winter', 'National defence', 'hiking', 'epigraphy', 'crafts and home industry', 'adornment', 'birthday', 'family portrait', 'hotels/inns', 'buildings', 'temperanc
# ...

# %%
thres_columns = ['musealia_additional_nr', 'event_type', 'participants_role', 'collection_additional_nr', 'damages', 'participant', 'location', 'material', 'technique']
data_dum = pd.get_dummies(data, columns = thres_columns)

# %%
data_dum.columns.size
# Out:
# 1955

# %%
#Save to csv:
data_dum.to_csv('data/prep_low_thres.csv')
