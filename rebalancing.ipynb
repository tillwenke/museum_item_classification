# %% [markdown]
# # Rebalancing
#
# - using different algorithms to rebalance our data

# %% [markdown]
# # Imports

# %%
# Imports
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import re 
from math import isnan

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_seq_items', None)
# dtype={'type': str} prevents being confused with data type for large data sets
train = pd.read_csv('data/train.csv', index_col='id', dtype={'type': str})
test = pd.read_csv('data/test.csv', index_col='id', dtype={'type': str})
train_translated = pd.read_csv('data/train_translated.csv', dtype={'type': str})
test_translated = pd.read_csv('data/test_translated.csv', index_col='id', dtype={'type': str})
combined_data = pd.read_csv('data/combined_data.csv', index_col='id', dtype={'type': str})
combined_data_translated = pd.read_csv('data/combined_data_translated.csv', index_col='id', dtype={'type': str})
combined_data_fully_translated = pd.read_csv('data/combined_data_fully_translated.csv', index_col='id', dtype={'type': str})
prep = pd.read_csv('data/prep.csv', index_col='id', dtype={'type': str})

# %%
from sklearn.preprocessing import LabelEncoder

# %%
data = prep.copy()
x = data.drop(['type', 'source'], axis=1)
#y = data['type']

# %%
y = data.type.astype("category")
# ROS cannot deal with string labels
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(y)
y = label_encoder.transform(y)

# %% [markdown]
# # RandomOverSampler(ROS)

# %%
from imblearn.over_sampling import RandomOverSampler
from collections import Counter

print(Counter(y).items())

def strat(data):
    b = Counter(y).values()
    a = Counter(y).keys()
    a = list(a)
    b = list(b)

    for i in range(len(a)):
        if b[i] < 500 :
            b[i] = 500
    return dict(zip(a, b))

print(strat(data))
ros = RandomOverSampler(sampling_strategy=strat(y), random_state=1)
X_res, y_res = ros.fit_resample(x, y)
print((Counter(y_res).items()))
# Out:
# dict_items([(29, 88), (36, 3747), (37, 2201), (22, 631), (8, 192), (21, 43), (45, 189), (30, 210), (50, 61), (1, 789), (4, 528), (41, 771), (42, 156), (48, 196), (43, 774), (11, 837), (2, 74), (26, 479), (14, 450), (6, 37), (18, 225), (54, 70), (27, 63), (33, 16), (51, 107), (19, 93), (34, 11), (35, 23), (28, 16), (25, 104), (0, 25), (9, 23), (12, 187), (38, 45), (39, 40), (16, 49), (10, 17), (23, 32), (5, 44), (53, 13), (3, 11), (32, 95), (13, 26), (31, 29), (24, 11), (46, 15), (44, 21), (47, 27), (52, 20), (7, 10), (49, 16), (17, 16), (20, 18), (15, 7), (40, 22), (55, 6000)])
# {29: 500, 36: 3747, 37: 2201, 22: 631, 8: 500, 21: 500, 45: 500, 30: 500, 50: 500, 1: 789, 4: 528, 41: 771, 42: 500, 48: 500, 43: 774, 11: 837, 2: 500, 26: 500, 14: 500, 6: 500, 18: 500, 54: 500, 27: 500, 33: 500, 51: 500, 19: 500, 34: 500, 35: 500, 28: 500, 25: 500, 0: 500, 9: 500, 12: 500, 38: 500, 39: 500, 16: 500, 10: 500, 23: 500, 5: 500, 53: 500, 3: 500, 32: 500, 13: 500, 31: 500, 24: 500, 46: 500, 44: 500, 47: 500, 52: 500, 7: 500, 49: 500, 17: 500, 20: 500, 15: 500, 40: 500, 55: 6000}
# dict_items([(29, 500), (36, 3747), (37, 2201), (22, 631), (8, 500), (21, 500), (45, 500), (30, 500), (50, 500), (1, 789), (4, 528), (41, 771), (42, 500), (48, 500), (43, 774), (11, 837), (2, 500), (26, 500), (14, 500), (6, 500), (18, 500), (54, 500), (27, 500), (33, 500), (51, 500), (19, 500), (34, 500), (35, 500), (28, 500), (25, 500), (0, 500), (9, 500), (12, 500), (38, 500), (39, 500), (16, 500), (10, 500), (23, 500), (5, 500), (53, 500), (3, 500), (32, 500), (13, 500), (31, 500), (24, 500), (46, 500), (44, 500), (47, 500), (52, 500), (7, 500), (49, 500), (17, 500), (20, 500), (15, 500), (40, 500), (55, 6000)])

# %% [markdown]
# # SMOTE

# %%
from imblearn.over_sampling import SMOTE, ADASYN
X_resSMOTE, y_resSMOTE = SMOTE().fit_resample(x, y)
print((Counter(y_res).items()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [25], line 2
#       1 from imblearn.over_sampling import SMOTE, ADASYN
# ----> 2 X_resSMOTE, y_resSMOTE = SMOTE().fit_resample(x, y)
#       3 print((Counter(y_res).items()))
#
# File c:\Users\flori\miniconda3\lib\site-packages\imblearn\base.py:77, in SamplerMixin.fit_resample(self, X, y)
#      75 check_classification_targets(y)
#      76 arrays_transformer = ArraysTransformer(X, y)
# ---> 77 X, y, binarize_y = self._check_X_y(X, y)
#      79 self.sampling_strategy_ = check_sampling_strategy(
#      80     self.sampling_strategy, y, self._sampling_type
#      81 )
#      83 output = self._fit_resample(X, y)
#
# File c:\Users\flori\miniconda3\lib\site-packages\imblearn\base.py:132, in BaseSampler._check_X_y(self, X, y, accept_sparse)
#     130     accept_sparse = ["csr", "csc"]
#     131 y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 132 X, y = self._validate_data(X, y, reset=True, accept_sparse=accept_sparse)
#     133 return X, y, binarize_y
#
# File c:\Users\flori\miniconda3\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\flori\miniconda3\lib\site-packages\sklearn\utils\validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File c:\Users\flori\miniconda3\lib\site-packages\sklearn\utils\validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File c:\Users\flori\miniconda3\lib\site-packages\sklearn\utils\validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input X contains NaN.
# SMOTE does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %% [markdown]
# # ADASYN

# %%
X_resADASYN, y_resADASYN = ADASYN().fit_resample(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 X_resADASYN, y_resADASYN = ADASYN().fit_resample(x, y)
#
# File c:\Users\flori\miniconda3\lib\site-packages\imblearn\base.py:77, in SamplerMixin.fit_resample(self, X, y)
#      75 check_classification_targets(y)
#      76 arrays_transformer = ArraysTransformer(X, y)
# ---> 77 X, y, binarize_y = self._check_X_y(X, y)
#      79 self.sampling_strategy_ = check_sampling_strategy(
#      80     self.sampling_strategy, y, self._sampling_type
#      81 )
#      83 output = self._fit_resample(X, y)
#
# File c:\Users\flori\miniconda3\lib\site-packages\imblearn\base.py:132, in BaseSampler._check_X_y(self, X, y, accept_sparse)
#     130     accept_sparse = ["csr", "csc"]
#     131 y, binarize_y = check_target_type(y, indicate_one_vs_all=True)
# --> 132 X, y = self._validate_data(X, y, reset=True, accept_sparse=accept_sparse)
#     133 return X, y, binarize_y
#
# File c:\Users\flori\miniconda3\lib\site-packages\sklearn\base.py:596, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     594         y = check_array(y, input_name="y", **check_y_params)
#     595     else:
# --> 596         X, y = check_X_y(X, y, **check_params)
#     597     out = X, y
#     599 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\flori\miniconda3\lib\site-packages\sklearn\utils\validation.py:1074, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1069         estimator_name = _check_estimator_name(estimator)
#    1070     raise ValueError(
#    1071         f"{estimator_name} requires y to be passed, but the target y is None"
#    1072     )
# -> 1074 X = check_array(
#    1075     X,
#    1076     accept_sparse=accept_sparse,
#    1077     accept_large_sparse=accept_large_sparse,
#    1078     dtype=dtype,
#    1079     order=order,
#    1080     copy=copy,
#    1081     force_all_finite=force_all_finite,
#    1082     ensure_2d=ensure_2d,
#    1083     allow_nd=allow_nd,
#    1084     ensure_min_samples=ensure_min_samples,
#    1085     ensure_min_features=ensure_min_features,
#    1086     estimator=estimator,
#    1087     input_name="X",
#    1088 )
#    1090 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1092 check_consistent_length(X, y)
#
# File c:\Users\flori\miniconda3\lib\site-packages\sklearn\utils\validation.py:899, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     893         raise ValueError(
#     894             "Found array with dim %d. %s expected <= 2."
#     895             % (array.ndim, estimator_name)
#     896         )
#     898     if force_all_finite:
# --> 899         _assert_all_finite(
#     900             array,
#     901             input_name=input_name,
#     902             estimator_name=estimator_name,
#     903             allow_nan=force_all_finite == "allow-nan",
#     904         )
#     906 if ensure_min_samples > 0:
#     907     n_samples = _num_samples(array)
#
# File c:\Users\flori\miniconda3\lib\site-packages\sklearn\utils\validation.py:146, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     124         if (
#     125             not allow_nan
#     126             and estimator_name
#    (...)
#     130             # Improve the error message on how to handle missing values in
#     131             # scikit-learn.
#     132             msg_err += (
#     133                 f"\n{estimator_name} does not accept missing values"
#     134                 " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     144                 "#estimators-that-handle-nan-values"
#     145             )
# --> 146         raise ValueError(msg_err)
#     148 # for object dtype data, we only check for NaNs (GH-13254)
#     149 elif X.dtype == np.dtype("object") and not allow_nan:
#
# ValueError: Input X contains NaN.
# ADASYN does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
print(data.head())
# Out:
#               ks  musealia_seria_nr  musealia_queue_nr  collection_queue_nr  \
# id
# 232170     118.0            12150.0              115.0                 44.0
# 2251378    102.0            12584.0               19.0                  1.0
# 2070466      NaN                NaN                NaN                 52.0
# 4085096  41691.0                NaN                NaN                  NaN
# 2697904    238.0             9424.0                NaN                  1.0
#
#          element_count            type source  material_Polish  \
# id
# 232170             1.0           medal  train                0
# 2251378            1.0           photo  train                0
# 2070466            1.0           photo  train                0
# 4085096            1.0  photo negative  train                0
# 2697904            1.0          letter  train                0
#
#          material_RC Photo Paper  material_a pearl  \
# id
# 232170                         0                 0
# 2251378                        0                 0
# 2070466                        0                 0
# 4085096                        0                 0
# 2697904                        0                 0
#
#          material_acetate cellulose film  material_albumen paper  \
# id
# 232170                                 0                       0
# 2251378                                0                       0
# 2070466                                0                       0
# 4085096                                0                       0
# 2697904                                0                       0
#
#          material_albumin paper  material_aluminium  material_amber  \
# id
# 232170                        0                   0               0
# 2251378                       0                   0               0
# 2070466                       0                   0               0
# 4085096                       0                   0               0
# 2697904                       0                   0               0
#
#          material_artificial fiber material  material_artificial leather  \
# id
# 232170                                    0                            0
# 2251378                                   0                            0
# 2070466                                   0                            0
# 4085096                                   0                            0
# 2697904                                   0                            0
#
#          material_artificial material  material_atlas  \
# id
# 232170                              0               0
# 2251378                             0               0
# 2070466                             0               0
# 4085096                             0               0
# 2697904                             0               0
#
#          material_ballpoint pen ink  material_birch  material_bone  \
# id
# 232170                            0               0              0
# 2251378                           0               0              0
# 2070466                           0               0              0
# 4085096                           0               0              0
# 2697904                           0               0              0
#
#          material_brass  material_brocade (clothing variety)  material_bronze  \
# id
# 232170                0                                    0                0
# 2251378               0                                    0                0
# 2070466               0                                    0                0
# 4085096               0                                    0                0
# 2697904               0                                    0                0
#
#          material_canvas  material_canvas (type of cloth)  material_cardboard  \
# id
# 232170                 0                                0                   0
# 2251378                0                                0                   0
# 2070466                0                                0                   0
# 4085096                0                                0                   0
# 2697904                0                                0                   0
#
#          material_cast iron  material_celluloid  material_ceramics  \
# id
# 232170                    0                   0                  0
# 2251378                   0                   0                  0
# 2070466                   0                   0                  0
# 4085096                   0                   0                  0
# 2697904                   0                   0                  0
#
#          material_chalk  material_chamois leather  material_chamotte  \
# id
# 232170                0                         0                  0
# 2251378               0                         0                  0
# 2070466               0                         0                  0
# 4085096               0                         0                  0
# 2697904               0                         0                  0
#
#          material_charcoal  material_chromogen emulsion  \
# id
# 232170                   0                            0
# 2251378                  0                            0
# 2070466                  0                            0
# 4085096                  0                            0
# 2697904                  0                            0
#
#          material_chromogen paper  material_clay  material_clothing variety  \
# id
# 232170                          0              0                          0
# 2251378                         0              0                          0
# 2070466                         0              0                          0
# 4085096                         0              0                          0
# 2697904                         0              0                          0
#
#          material_collodion paper  material_colloid paper  material_colour  \
# id
# 232170                          0                       0                0
# 2251378                         0                       0                0
# 2070466                         0                       0                0
# 4085096                         0                       0                0
# 2697904                         0                       0                0
#
#          material_copper  material_cotton  material_crepe  \
# id
# 232170                 0                0               0
# 2251378                0                0               0
# 2070466                0                0               0
# 4085096                0                0               0
# 2697904                0                0               0
#
#          material_crepe (cloth type)  material_crystal  \
# id
# 232170                             0                 0
# 2251378                            0                 0
# 2070466                            0                 0
# 4085096                            0                 0
# 2697904                            0                 0
#
#          material_diffusion paper  material_email  material_emulsion  \
# id
# 232170                          0               0                  0
# 2251378                         0               0                  0
# 2070466                         0               0                  0
# 4085096                         0               0                  0
# 2697904                         0               0                  0
#
#          material_enamel paint  material_faience  material_feather  \
# id
# 232170                       0                 0                 0
# 2251378                      0                 0                 0
# 2070466                      0                 0                 0
# 4085096                      0                 0                 0
# 2697904                      0                 0                 0
#
#          material_film  material_film (material)  material_flint  \
# id
# 232170               0                         0               0
# 2251378              0                         0               0
# 2070466              0                         0               0
# 4085096              0                         0               0
# 2697904              0                         0               0
#
#          material_from the bat  material_glass  material_gold  \
# id
# 232170                       0               0              0
# 2251378                      0               0              0
# 2070466                      0               0              0
# 4085096                      0               0              0
# 2697904                      0               0              0
#
#          material_granite  material_graphite  material_gypsum  \
# id
# 232170                  0                  0                0
# 2251378                 0                  0                0
# 2070466                 0                  0                0
# 4085096                 0                  0                0
# 2697904                 0                  0                0
#
#          material_handmade paper  material_ink  material_iron  material_kalka  \
# id
# 232170                         0             0              0               0
# 2251378                        0             0              0               0
# 2070466                        0             0              0               0
# 4085096                        0             0              0               0
# 2697904                        0             0              0               0
#
#          material_knitwear  material_leotard (type of clothing)  \
# id
# 232170                   0                                    0
# 2251378                  0                                    0
# 2070466                  0                                    0
# 4085096                  0                                    0
# 2697904                  0                                    0
#
#          material_linen  material_mascara  material_metal  \
# id
# 232170                0                 0               1
# 2251378               0                 0               0
# 2070466               0                 0               0
# 4085096               0                 0               0
# 2697904               0                 0               0
#
#          material_metal fibers  material_moire (clothing variety)  \
# id
# 232170                       0                                  0
# 2251378                      0                                  0
# 2070466                      0                                  0
# 4085096                      0                                  0
# 2697904                      0                                  0
#
#          material_movie  material_nan  material_newsprint  \
# id
# 232170                0             0                   0
# 2251378               0             0                   0
# 2070466               0             1                   0
# 4085096               0             0                   0
# 2697904               0             0                   0
#
#          material_nitrocellulose film  material_nut  material_oil paint  \
# id
# 232170                              0             0                   0
# 2251378                             0             0                   0
# 2070466                             0             0                   0
# 4085096                             0             0                   0
# 2697904                             0             0                   0
#
#          material_organic matter  material_paper  material_papier mache  \
# id
# 232170                         0               0                      0
# 2251378                        0               0                      0
# 2070466                        0               0                      0
# 4085096                        0               0                      0
# 2697904                        0               1                      0
#
#          material_photo emulsion  material_photo material  \
# id
# 232170                         0                        0
# 2251378                        0                        0
# 2070466                        0                        0
# 4085096                        0                        0
# 2697904                        0                        0
#
#          material_photo paper  material_photo plate  \
# id
# 232170                      0                     0
# 2251378                     0                     0
# 2070466                     0                     0
# 4085096                     0                     0
# 2697904                     0                     0
#
#          material_photographic material  material_plastic  \
# id
# 232170                                0                 0
# 2251378                               1                 0
# 2070466                               0                 0
# 4085096                               1                 0
# 2697904                               0                 0
#
#          material_plastic mass  material_plywood  material_porcelain  \
# id
# 232170                       0                 0                   0
# 2251378                      0                 0                   0
# 2070466                      0                 0                   0
# 4085096                      0                 0                   0
# 2697904                      0                 0                   0
#
#          material_printing ink  material_quartz  material_rubber  \
# id
# 232170                       0                0                0
# 2251378                      0                0                0
# 2070466                      0                0                0
# 4085096                      0                0                0
# 2697904                      0                0                0
#
#          material_salt paper  material_silk  material_silver  \
# id
# 232170                     0              0                0
# 2251378                    0              0                0
# 2070466                    0              0                0
# 4085096                    0              0                0
# 2697904                    0              0                0
#
#          material_silver gelatin emulsion  material_silver gelatin paper  \
# id
# 232170                                  0                              0
# 2251378                                 0                              0
# 2070466                                 0                              0
# 4085096                                 0                              0
# 2697904                                 0                              0
#
#          material_skin  material_slate  material_stone  \
# id
# 232170               0               0               0
# 2251378              0               0               0
# 2070466              0               0               0
# 4085096              0               0               0
# 2697904              0               0               0
#
#          material_synthetic fibers  material_synthetic material  \
# id
# 232170                           0                            0
# 2251378                          0                            0
# 2070466                          0                            0
# 4085096                          0                            0
# 2697904                          0                            0
#
#          material_tempera  material_textile  material_tin  material_trillion  \
# id
# 232170                  0                 0             0                  0
# 2251378                 0                 0             0                  0
# 2070466                 0                 0             0                  0
# 4085096                 0                 0             0                  0
# 2697904                 0                 0             0                  0
#
#          material_watercolor paint  material_wax  material_white metal  \
# id
# 232170                           0             0                     0
# 2251378                          0             0                     0
# 2070466                          0             0                     0
# 4085096                          0             0                     0
# 2697904                          0             0                     0
#
#          material_wire  material_wood  material_wood material  \
# id
# 232170               0              0                       0
# 2251378              0              0                       0
# 2070466              0              0                       0
# 4085096              0              0                       0
# 2697904              0              0                       0
#
#          material_wooden board  material_wool  material_yarn  \
# id
# 232170                       0              0              0
# 2251378                      0              0              0
# 2070466                      0              0              0
# 4085096                      0              0              0
# 2697904                      0              0              0
#
#          technique_(close/together) sewing  technique_addition  \
# id
# 232170                                   0                   0
# 2251378                                  0                   0
# 2070466                                  0                   0
# 4085096                                  0                   0
# 2697904                                  0                   0
#
#          technique_aquatint  technique_ballpoint pen  \
# id
# 232170                    0                        0
# 2251378                   0                        0
# 2070466                   0                        0
# 4085096                   0                        0
# 2697904                   0                        0
#
#          technique_binding techniques  technique_black and white photo  \
# id
# 232170                              0                                0
# 2251378                             0                                0
# 2070466                             0                                0
# 4085096                             0                                0
# 2697904                             0                                0
#
#          technique_black and white photography  technique_bronzing  \
# id
# 232170                                       0                   0
# 2251378                                      0                   0
# 2070466                                      0                   0
# 4085096                                      0                   0
# 2697904                                      0                   0
#
#          technique_brushing  technique_burning  technique_carving  \
# id
# 232170                    0                  0                  0
# 2251378                   0                  0                  0
# 2070466                   0                  0                  0
# 4085096                   0                  0                  0
# 2697904                   0                  0                  0
#
#          technique_casting  technique_chalk  technique_charcoal  \
# id
# 232170                   0                0                   0
# 2251378                  0                0                   0
# 2070466                  0                0                   0
# 4085096                  0                0                   0
# 2697904                  0                0                   0
#
#          technique_chromogen procedure  technique_collage  \
# id
# 232170                               0                  0
# 2251378                              0                  0
# 2070466                              0                  0
# 4085096                              0                  0
# 2697904                              0                  0
#
#          technique_collotype  technique_color photo  \
# id
# 232170                     0                      0
# 2251378                    0                      0
# 2070466                    0                      0
# 4085096                    0                      0
# 2697904                    0                      0
#
#          technique_color photography  technique_colored chalk  \
# id
# 232170                             0                        0
# 2251378                            0                        0
# 2070466                            0                        0
# 4085096                            0                        0
# 2697904                            0                        0
#
#          technique_colored pencil  technique_coloring  \
# id
# 232170                          0                   0
# 2251378                         0                   0
# 2070466                         0                   0
# 4085096                         0                   0
# 2697904                         0                   0
#
#          technique_copper engraving  technique_copying  \
# id
# 232170                            0                  0
# 2251378                           0                  0
# 2070466                           0                  0
# 4085096                           0                  0
# 2697904                           0                  0
#
#          technique_crayon drawing  technique_croaking  technique_crocheting  \
# id
# 232170                          0                   0                     0
# 2251378                         0                   0                     0
# 2070466                         0                   0                     0
# 4085096                         0                   0                     0
# 2697904                         0                   0                     0
#
#          technique_cutting  technique_cuttlefish  technique_daguerreotype  \
# id
# 232170                   0                     0                        0
# 2251378                  0                     0                        0
# 2070466                  0                     0                        0
# 4085096                  0                     0                        0
# 2697904                  0                     0                        0
#
#          technique_digital photography  technique_digital printing  \
# id
# 232170                               0                           0
# 2251378                              0                           0
# 2070466                              0                           0
# 4085096                              0                           0
# 2697904                              0                           0
#
#          technique_drawing  technique_electronic imaging  \
# id
# 232170                   0                             0
# 2251378                  0                             0
# 2070466                  0                             0
# 4085096                  0                             0
# 2697904                  0                             0
#
#          technique_embroidery  technique_enamelling  technique_engraving  \
# id
# 232170                      0                     0                    0
# 2251378                     0                     0                    0
# 2070466                     0                     0                    0
# 4085096                     0                     0                    0
# 2697904                     0                     0                    0
#
#          technique_etching  technique_felt tip pen  \
# id
# 232170                   0                       0
# 2251378                  0                       0
# 2070466                  0                       0
# 4085096                  0                       0
# 2697904                  0                       0
#
#          technique_glass technology  technique_gouache  technique_graphics  \
# id
# 232170                            0                  0                   0
# 2251378                           0                  0                   0
# 2070466                           0                  0                   0
# 4085096                           0                  0                   0
# 2697904                           0                  0                   0
#
#          technique_graphite  technique_handicraft  technique_handwriting  \
# id
# 232170                    0                     0                      0
# 2251378                   0                     0                      0
# 2070466                   0                     0                      0
# 4085096                   0                     0                      0
# 2697904                   0                     0                      0
#
#          technique_ink  technique_ink drawing  technique_intarsia  \
# id
# 232170               0                      0                   0
# 2251378              0                      0                   0
# 2070466              0                      0                   0
# 4085096              0                      0                   0
# 2697904              0                      0                   0
#
#          technique_kiln ceramics  technique_knitting  \
# id
# 232170                         0                   0
# 2251378                        0                   0
# 2070466                        0                   0
# 4085096                        0                   0
# 2697904                        0                   0
#
#          technique_letterpress with raster cliché  technique_linocut  \
# id
# 232170                                          0                  0
# 2251378                                         0                  0
# 2070466                                         0                  0
# 4085096                                         0                  0
# 2697904                                         0                  0
#
#          technique_lithography  technique_manuscript  technique_marker  \
# id
# 232170                       0                     0                 0
# 2251378                      0                     0                 0
# 2070466                      0                     0                 0
# 4085096                      0                     0                 0
# 2697904                      0                     1                 0
#
#          technique_mascara  technique_mezzotinto  technique_mixed media  \
# id
# 232170                   0                     0                      0
# 2251378                  0                     0                      0
# 2070466                  0                     0                      0
# 4085096                  0                     0                      0
# 2697904                  0                     0                      0
#
#          technique_modeling  technique_molding  technique_monotypy  \
# id
# 232170                    0                  0                   0
# 2251378                   0                  0                   0
# 2070466                   0                  0                   0
# 4085096                   0                  0                   0
# 2697904                   0                  0                   0
#
#          technique_nan  technique_offset printing  technique_oil  \
# id
# 232170               1                          0              0
# 2251378              1                          0              0
# 2070466              1                          0              0
# 4085096              1                          0              0
# 2697904              0                          0              0
#
#          technique_oil painting  technique_painting  \
# id
# 232170                        0                   0
# 2251378                       0                   0
# 2070466                       0                   0
# 4085096                       0                   0
# 2697904                       0                   0
#
#          technique_painting techniques  technique_pannotype  technique_pastel  \
# id
# 232170                               0                    0                 0
# 2251378                              0                    0                 0
# 2070466                              0                    0                 0
# 4085096                              0                    0                 0
# 2697904                              0                    0                 0
#
#          technique_pen  technique_photographic techniques  \
# id
# 232170               0                                  0
# 2251378              0                                  0
# 2070466              0                                  0
# 4085096              0                                  0
# 2697904              0                                  0
#
#          technique_photography  technique_photogravure  \
# id
# 232170                       0                       0
# 2251378                      0                       0
# 2070466                      0                       0
# 4085096                      0                       0
# 2697904                      0                       0
#
#          technique_photolithography  technique_photomechanical printing  \
# id
# 232170                            0                                   0
# 2251378                           0                                   0
# 2070466                           0                                   0
# 4085096                           0                                   0
# 2697904                           0                                   0
#
#          technique_polishing  technique_pressing  technique_printing  \
# id
# 232170                     0                   0                   0
# 2251378                    0                   0                   0
# 2070466                    0                   0                   0
# 4085096                    0                   0                   0
# 2697904                    0                   0                   0
#
#          technique_raster printing  technique_relief  \
# id
# 232170                           0                 0
# 2251378                          0                 0
# 2070466                          0                 0
# 4085096                          0                 0
# 2697904                          0                 0
#
#          technique_rishel casting heel  technique_sanguine  \
# id
# 232170                               0                   0
# 2251378                              0                   0
# 2070466                              0                   0
# 4085096                              0                   0
# 2697904                              0                   0
#
#          technique_serigraphy  technique_sewing  technique_sketch  \
# id
# 232170                      0                 0                 0
# 2251378                     0                 0                 0
# 2070466                     0                 0                 0
# 4085096                     0                 0                 0
# 2697904                     0                 0                 0
#
#          technique_slide  technique_soft varnish  technique_stamping  \
# id
# 232170                 0                       0                   0
# 2251378                0                       0                   0
# 2070466                0                       0                   0
# 4085096                0                       0                   0
# 2697904                0                       0                   0
#
#          technique_steel engraving  technique_strengthening  \
# id
# 232170                           0                        0
# 2251378                          0                        0
# 2070466                          0                        0
# 4085096                          0                        0
# 2697904                          0                        0
#
#          technique_taking pictures  technique_tempera  technique_toning  \
# id
# 232170                           0                  0                 0
# 2251378                          0                  0                 0
# 2070466                          0                  0                 0
# 4085096                          0                  0                 0
# 2697904                          0                  0                 0
#
#          technique_turning  technique_typescript  technique_typing  \
# id
# 232170                   0                     0                 0
# 2251378                  0                     0                 0
# 2070466                  0                     0                 0
# 4085096                  0                     0                 0
# 2697904                  0                     0                 0
#
#          technique_undermining  technique_watercolor  \
# id
# 232170                       0                     0
# 2251378                      0                     0
# 2070466                      0                     0
# 4085096                      0                     0
# 2697904                      0                     0
#
#          technique_wet collodion process  technique_wood engraving  \
# id
# 232170                                 0                         0
# 2251378                                0                         0
# 2070466                                0                         0
# 4085096                                0                         0
# 2697904                                0                         0
#
#          technique_woodcut  technique_writing  * IN *  amount IN pieces  \
# id
# 232170                   0                  0     0.0               0.0
# 2251378                  0                  0     0.0               0.0
# 2070466                  0                  0     0.0               0.0
# 4085096                  0                  0     0.0               0.0
# 2697904                  0                  0     0.0               0.0
#
#          circumference IN cm  diameter IN cm  distance IN cm  \
# id
# 232170                   0.0             4.0             0.0
# 2251378                  0.0             0.0             0.0
# 2070466                  0.0             0.0             0.0
# 4085096                  0.0             0.0             0.0
# 2697904                  0.0             0.0             0.0
#
#          document volume IN pages  height IN cm  image height IN cm  \
# id
# 232170                        0.0           0.0                 0.0
# 2251378                       0.0           0.0                 0.0
# 2070466                       0.0           0.0                 0.0
# 4085096                       0.0           0.0                 0.0
# 2697904                       0.0           0.0                 0.0
#
#          image width IN cm  length IN cm  page height IN cm  page width IN cm  \
# id
# 232170                 0.0           0.0                0.0               0.0
# 2251378                0.0           0.0                0.0               0.0
# 2070466                0.0           0.0                0.0               0.0
# 4085096                0.0           0.0                0.0               0.0
# 2697904                0.0           0.0                0.0               0.0
#
#          paper format IN A6  print volume IN pages  size (clothing) IN number  \
# id
# 232170                  0.0                    0.0                        0.0
# 2251378                 0.0                    0.0                        0.0
# 2070466                 0.0                    0.0                        0.0
# 4085096                 0.0                    0.0                        0.0
# 2697904                 0.0                    0.0                        0.0
#
#          thickness IN cm  time/ duration IN century  \
# id
# 232170               0.0                        0.0
# 2251378              0.0                        0.0
# 2070466              0.0                        0.0
# 4085096              0.0                        0.0
# 2697904              0.0                        0.0
#
#          volume of the book IN pages  volume of wood IN dm3  \
# id
# 232170                           0.0                    0.0
# 2251378                          0.0                    0.0
# 2070466                          0.0                    0.0
# 4085096                          0.0                    0.0
# 2697904                          0.0                    0.0
#
#          volume of writing IN autograph  weight IN g  width IN cm  \
# id
# 232170                              0.0          0.0          0.0
# 2251378                             0.0          0.0          0.0
# 2070466                             0.0          0.0          0.0
# 4085096                             0.0          0.0          0.0
# 2697904                             0.0          0.0          0.0
#
#          film frame IN mm²_height  film frame IN mm²_width  \
# id
# 232170                        0.0                      0.0
# 2251378                       0.0                      0.0
# 2070466                       0.0                      0.0
# 4085096                      60.0                     60.0
# 2697904                       0.0                      0.0
#
#          negative format IN mm²_height  negative format IN mm²_width  \
# id
# 232170                             0.0                           0.0
# 2251378                            0.0                           0.0
# 2070466                            0.0                           0.0
# 4085096                            0.0                           0.0
# 2697904                            0.0                           0.0
#
#          photo format IN mm²_height  photo format IN mm²_width  startYear  \
# id
# 232170                          0.0                        0.0       1979
# 2251378                         0.0                        0.0       1938
# 2070466                         0.0                        0.0          0
# 4085096                         0.0                        0.0       1969
# 2697904                         0.0                        0.0          0
#
#          startMonth  startDay  endYear  endMonth  endDay  location_city  \
# id
# 232170            0         0        0         0       0              1
# 2251378           0         0        0         0       0              0
# 2070466           0         0        0         0       0              0
# 4085096           1         1        0         0       0              0
# 2697904           0         0        0         0       0              0
#
#          location_building  location_street  location_country  \
# id
# 232170                   0                0                 0
# 2251378                  0                0                 0
# 2070466                  0                0                 0
# 4085096                  0                0                 0
# 2697904                  0                0                 0
#
#          location_address  state_bad  state_good  state_satisfactory  \
# id
# 232170                  0          0           1                   0
# 2251378                 0          0           1                   0
# 2070466                 0          0           1                   0
# 4085096                 0          0           0                   1
# 2697904                 0          0           0                   1
#
#          state_unspecified  state_very bad  collection_mark_A  \
# id
# 232170                   0               0                  0
# 2251378                  0               0                  0
# 2070466                  0               0                  0
# 4085096                  0               0                  0
# 2697904                  0               0                  0
#
#          collection_mark_Ab  collection_mark_Af  collection_mark_Aj  \
# id
# 232170                    0                   0                   1
# 2251378                   0                   0                   0
# 2070466                   0                   0                   0
# 4085096                   0                   0                   0
# 2697904                   0                   0                   0
#
#          collection_mark_Ar  collection_mark_D  collection_mark_Df  \
# id
# 232170                    0                  0                   0
# 2251378                   0                  0                   0
# 2070466                   0                  0                   0
# 4085096                   0                  0                   0
# 2697904                   0                  0                   0
#
#          collection_mark_Dg  collection_mark_E  collection_mark_F  \
# id
# 232170                    0                  0                  0
# ...
# 4085096                           0                         0
# 2697904                           0                         0
#
#          location_tänav K. Türnpuu  location_tänav Kaarli puiestee  \
# id
# 232170                           0                               0
# 2251378                          0                               0
# 2070466                          0                               0
# 4085096                          0                               0
# 2697904                          0                               0
#
#          location_tänav Kalju  location_tänav Kaubamaja 1  \
# id
# 232170                      0                           0
# 2251378                     0                           0
# 2070466                     0                           0
# 4085096                     0                           0
# 2697904                     0                           0
#
#          location_tänav Kevade  location_tänav Koidu  location_tänav Kopli  \
# id
# 232170                       0                     0                     0
# 2251378                      0                     0                     0
# 2070466                      0                     0                     0
# 4085096                      0                     0                     0
# 2697904                      0                     0                     0
#
#          location_tänav Kullassepa  location_tänav Kunderi  \
# id
# 232170                           0                       0
# 2251378                          0                       0
# 2070466                          0                       0
# 4085096                          0                       0
# 2697904                          0                       0
#
#          location_tänav Laagna tee  location_tänav Lai  \
# id
# 232170                           0                   0
# 2251378                          0                   0
# 2070466                          0                   0
# 4085096                          0                   0
# 2697904                          0                   0
#
#          location_tänav Lennuki  location_tänav Liivalaia  \
# id
# 232170                        0                         0
# 2251378                       0                         0
# 2070466                       0                         0
# 4085096                       0                         0
# 2697904                       0                         0
#
#          location_tänav Loode  location_tänav Luise  location_tänav Maakri  \
# id
# 232170                      0                     0                      0
# 2251378                     0                     0                      0
# 2070466                     0                     0                      0
# 4085096                     0                     0                      0
# 2697904                     0                     0                      0
#
#          location_tänav Malmi  location_tänav Maneeži  location_tänav Mooni  \
# id
# 232170                      0                       0                     0
# 2251378                     0                       0                     0
# 2070466                     0                       0                     0
# 4085096                     0                       0                     0
# 2697904                     0                       0                     0
#
#          location_tänav Mäekalda  location_tänav Narva maantee  \
# id
# 232170                         0                             0
# 2251378                        0                             0
# 2070466                        0                             0
# 4085096                        0                             0
# 2697904                        0                             0
#
#          location_tänav Nõmme tee  location_tänav Odra  \
# id
# 232170                          0                    0
# 2251378                         0                    0
# 2070466                         0                    0
# 4085096                         0                    0
# 2697904                         0                    0
#
#          location_tänav P. Süda  location_tänav Paldiski maantee  \
# id
# 232170                        0                                0
# 2251378                       0                                0
# 2070466                       0                                0
# 4085096                       0                                0
# 2697904                       0                                0
#
#          location_tänav Pikk  location_tänav Pikk jalg  \
# id
# 232170                     0                         0
# 2251378                    0                         0
# 2070466                    0                         0
# 4085096                    0                         0
# 2697904                    0                         0
#
#          location_tänav Pirita tee  location_tänav Pronksi  \
# id
# 232170                           0                       0
# 2251378                          0                       0
# 2070466                          0                       0
# 4085096                          0                       0
# 2697904                          0                       0
#
#          location_tänav Pärnu maantee  location_tänav Rävala pst  \
# id
# 232170                              0                          0
# 2251378                             0                          0
# 2070466                             0                          0
# 4085096                             0                          0
# 2697904                             0                          0
#
#          location_tänav Salme  location_tänav Suur-Karja  location_tänav Sõle  \
# id
# 232170                      0                          0                    0
# 2251378                     0                          0                    0
# 2070466                     0                          0                    0
# 4085096                     0                          0                    0
# 2697904                     0                          0                    0
#
#          location_tänav Sõpruse puiestee  location_tänav Süda  \
# id
# 232170                                 0                    0
# 2251378                                0                    0
# 2070466                                0                    0
# 4085096                                0                    0
# 2697904                                0                    0
#
#          location_tänav Tartu maantee  location_tänav Tatari  \
# id
# 232170                              0                      0
# 2251378                             0                      0
# 2070466                             0                      0
# 4085096                             0                      0
# 2697904                             0                      0
#
#          location_tänav Tehnika  location_tänav Toom-Kuninga  \
# id
# 232170                        0                            0
# 2251378                       0                            0
# 2070466                       0                            0
# 4085096                       0                            0
# 2697904                       0                            0
#
#          location_tänav Tuvi  location_tänav Tööstuse  \
# id
# 232170                     0                        0
# 2251378                    0                        0
# 2070466                    0                        0
# 4085096                    0                        0
# 2697904                    0                        0
#
#          location_tänav Uus-Sadama  location_tänav Vabaduse väljak  \
# id
# 232170                           0                               0
# 2251378                          0                               0
# 2070466                          0                               0
# 4085096                          0                               0
# 2697904                          0                               0
#
#          location_tänav Vabriku  location_tänav Vana-Viru  \
# id
# 232170                        0                         0
# 2251378                       0                         0
# 2070466                       0                         0
# 4085096                       0                         0
# 2697904                       0                         0
#
#          location_tänav Vene turg  location_tänav Viljandi 21  \
# id
# 232170                          0                           0
# 2251378                         0                           0
# 2070466                         0                           0
# 4085096                         0                           0
# 2697904                         0                           0
#
#          location_tänav Viru  location_tänav Viru väljak  \
# id
# 232170                     0                           0
# 2251378                    0                           0
# 2070466                    0                           0
# 4085096                    0                           0
# 2697904                    0                           0
#
#          location_tänav Väike-Ameerika  location_tänav Väike-Laagri  \
# id
# 232170                               0                            0
# 2251378                              0                            0
# 2070466                              0                            0
# 4085096                              0                            0
# 2697904                              0                            0
#
#          location_tänav Võidu väljak  location_tänav Wismari  \
# id
# 232170                             0                       0
# 2251378                            0                       0
# 2070466                            0                       0
# 4085096                            0                       0
# 2697904                            0                       0
#
#          location_vabariik Eesti NSV  location_vald Helme  location_vald Kõpu  \
# id
# 232170                             0                    0                   0
# 2251378                            0                    0                   0
# 2070466                            0                    0                   0
# 4085096                            0                    0                   0
# 2697904                            0                    0                   0
#
#          location_vald Rakke  location_vald Vigala  location_väin Vigala vald  \
# id
# 232170                     0                     0                          0
# 2251378                    0                     0                          0
# 2070466                    0                     0                          0
# 4085096                    0                     0                          0
# 2697904                    0                     0                          0
#
#          location_has_a_value  participant_has_a_value  damages_has_a_value  \
# id
# 232170                      1                        1                    0
# 2251378                     0                        0                    0
# 2070466                     0                        0                    0
# 4085096                     0                        1                    0
# 2697904                     0                        0                    0
#
#          collection_additional_nr_has_a_value  participants_role_has_a_value  \
# id
# 232170                                      1                              1
# 2251378                                     1                              0
# 2070466                                     0                              0
# 4085096                                     1                              1
# 2697904                                     1                              0
#
#          event_type_has_a_value  musealia_additional_nr_has_a_value  \
# id
# 232170                        1                                   0
# 2251378                       1                                   0
# 2070466                       0                                   0
# 4085096                       1                                   0
# 2697904                       0                                   0
#
#          is_original_has_a_value  class_has_a_value  museum_abbr_has_a_value  \
# id
# 232170                         1                  0                        1
# 2251378                        0                  0                        1
# 2070466                        0                  0                        1
# 4085096                        1                  0                        1
# 2697904                        1                  0                        1
#
#          color_has_a_value  collection_mark_has_a_value  state_has_a_value  \
# id
# 232170                   1                            1                  1
# 2251378                  0                            1                  1
# 2070466                  0                            1                  1
# 4085096                  0                            1                  1
# 2697904                  0                            1                  1
#
#          technique_has_a_value  material_has_a_value
# id
# 232170                       0                     1
# 2251378                      0                     1
# 2070466                      0                     0
# 4085096                      0                     1
# 2697904                      1                     1
